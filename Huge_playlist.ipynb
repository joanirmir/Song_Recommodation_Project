# %%
import config

# %%
c_id = config.c_id

# %%
c_se = config.c_se

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= c_id,
                                                           client_secret= c_se))

# %%
playlist = sp.user_playlist_tracks("spotify", "1Ien12ACUL1Q2V2xIra3WO",market="GB")

# %%
print(list(playlist.keys()))
print("Total number of songs in the playlist: ",playlist["total"])
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  9521
# 100

# %%
## Using this function
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
len(get_playlist_tracks("spotify", "1Ien12ACUL1Q2V2xIra3WO"))
# Out:
# 9521

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1Ien12ACUL1Q2V2xIra3WO/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2021-01-23T10:04:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/76Plkuk64KSXfG04kwxNZk'},
#        'href': 'https://api.spotify.com/v1/artists/76Plkuk64KSXfG04kwxNZk',
#        'id': '76Plkuk64KSXfG04kwxNZk',
#        'name': 'Koi',
#        'type': 'artist',
#        'uri': 'spotify:artist:76Plkuk64KSXfG04kwxNZk'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7HZ8xagY8szB8cqhACjjCl'},
#      'href': 'https://api.spotify.com/v1/albums/7HZ8xagY8szB8cqhACjjCl',
#      'id': '7HZ8xagY8szB8cqhACjjCl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738bec56ebf032e78405eba635',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028bec56ebf032e78405eba635',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518bec56ebf032e78405eba635',
#        'width': 64}],
#      'name': "before it's too late",
#      'release_date': '2020-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7HZ8xagY8szB8cqhACjjCl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/76Plkuk64KSXfG04kwxNZk'},
#       'href': 'https://api.spotify.com/v1/artists/76Plkuk64KSXfG04kwxNZk',
#       'id': '76Plkuk64KSXfG04kwxNZk',
#       'name': 'Koi',
#       'type': 'artist',
#       'uri': 'spotify:artist:76Plkuk64KSXfG04kwxNZk'}],
#     'disc_number': 1,
#     'duration_ms': 103473,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZDA62001992'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2pTW1GkqQ6dPTBOff2ZqQc'},
#     'href': 'https://api.spotify.com/v1/tracks/2pTW1GkqQ6dPTBOff2ZqQc',
#     'id': '2pTW1GkqQ6dPTBOff2ZqQc',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'beverly',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3dbae1c597f97183edb06c38e4d3b8def3e22d98?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:2pTW1GkqQ6dPTBOff2ZqQc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:03:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#        'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#        'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#        'name': 'David Guetta',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1fAn5gw4Q5HN8Wpx2neYd2'},
#      'href': 'https://api.spotify.com/v1/albums/1fAn5gw4Q5HN8Wpx2neYd2',
#      'id': '1fAn5gw4Q5HN8Wpx2neYd2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd5ba80ea2ad342e488ba54d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd5ba80ea2ad342e488ba54d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd5ba80ea2ad342e488ba54d',
#        'width': 64}],
#      'name': 'Nothing but the Beat Ultimate',
#      'release_date': '2011-08-24',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:1fAn5gw4Q5HN8Wpx2neYd2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#       'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#       'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#       'name': 'David Guetta',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#       'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#       'id': '5WUlDfRSoLAfcVSX1WnrxN',
#       'name': 'Sia',
#       'type': 'artist',
#       'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'}],
#     'disc_number': 1,
#     'duration_ms': 245040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB28K1100036'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2dOTkLZFbpNXrhc24CnTFd'},
#     'href': 'https://api.spotify.com/v1/tracks/2dOTkLZFbpNXrhc24CnTFd',
#     'id': '2dOTkLZFbpNXrhc24CnTFd',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/47Z5890IcjSed81ldeLgqc'},
#      'href': 'https://api.spotify.com/v1/tracks/47Z5890IcjSed81ldeLgqc',
#      'id': '47Z5890IcjSed81ldeLgqc',
#      'type': 'track',
#      'uri': 'spotify:track:47Z5890IcjSed81ldeLgqc'},
#     'name': 'Titanium (feat. Sia)',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/06392eaab5975806f18d8411f5b58f50b1899198?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2dOTkLZFbpNXrhc24CnTFd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#        'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#        'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#        'name': 'Kendrick Lamar',
#        'type': 'artist',
#        'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4eLPsYPBmXABThSJ821sqY'},
#      'href': 'https://api.spotify.com/v1/albums/4eLPsYPBmXABThSJ821sqY',
#      'id': '4eLPsYPBmXABThSJ821sqY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738b52c6b9bc4e43d873869699',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028b52c6b9bc4e43d873869699',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518b52c6b9bc4e43d873869699',
#        'width': 64}],
#      'name': 'DAMN.',
#      'release_date': '2017-04-14',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4eLPsYPBmXABThSJ821sqY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qBKjEOanahMxlRojwCzhI'},
#       'href': 'https://api.spotify.com/v1/artists/3qBKjEOanahMxlRojwCzhI',
#       'id': '3qBKjEOanahMxlRojwCzhI',
#       'name': 'Zacari',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qBKjEOanahMxlRojwCzhI'}],
#     'disc_number': 1,
#     'duration_ms': 213400,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71703088'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6PGoSes0D9eUDeeAafB2As'},
#     'href': 'https://api.spotify.com/v1/tracks/6PGoSes0D9eUDeeAafB2As',
#     'id': '6PGoSes0D9eUDeeAafB2As',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'LOVE. FEAT. ZACARI.',
#     'popularity': 83,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:6PGoSes0D9eUDeeAafB2As'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#        'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#        'id': '2cFrymmkijnjDg9SS92EPM',
#        'name': 'blackbear',
#        'type': 'artist',
#        'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0a8WSH44kA5hR4MQ6LyFDB'},
#      'href': 'https://api.spotify.com/v1/albums/0a8WSH44kA5hR4MQ6LyFDB',
#      'id': '0a8WSH44kA5hR4MQ6LyFDB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736c112ab47442b526755ffe36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026c112ab47442b526755ffe36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516c112ab47442b526755ffe36',
#        'width': 64}],
#      'name': 'digital druglord',
#      'release_date': '2017-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0a8WSH44kA5hR4MQ6LyFDB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#       'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#       'id': '2cFrymmkijnjDg9SS92EPM',
#       'name': 'blackbear',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#     'disc_number': 1,
#     'duration_ms': 212027,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USLD91700850'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Se3x9ANMLv0dCDsjGmEjh'},
#     'href': 'https://api.spotify.com/v1/tracks/6Se3x9ANMLv0dCDsjGmEjh',
#     'id': '6Se3x9ANMLv0dCDsjGmEjh',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3sTCfUmYXSVWDacTd6uMbQ'},
#      'href': 'https://api.spotify.com/v1/tracks/3sTCfUmYXSVWDacTd6uMbQ',
#      'id': '3sTCfUmYXSVWDacTd6uMbQ',
#      'type': 'track',
#      'uri': 'spotify:track:3sTCfUmYXSVWDacTd6uMbQ'},
#     'name': 'do re mi',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e7152fa0864a8bb8efd956e46cb7b0068a266a05?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6Se3x9ANMLv0dCDsjGmEjh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oQJQUIpJFFnfKvHJA0xBu'},
#        'href': 'https://api.spotify.com/v1/artists/2oQJQUIpJFFnfKvHJA0xBu',
#        'id': '2oQJQUIpJFFnfKvHJA0xBu',
#        'name': 'The City of Prague Philharmonic Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:2oQJQUIpJFFnfKvHJA0xBu'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5MBTOwS0yfq5hDhzRacsh2'},
#      'href': 'https://api.spotify.com/v1/albums/5MBTOwS0yfq5hDhzRacsh2',
#      'id': '5MBTOwS0yfq5hDhzRacsh2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738f10b56b3f9e9096472c550d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028f10b56b3f9e9096472c550d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518f10b56b3f9e9096472c550d',
#        'width': 64}],
#      'name': 'Music from the Hobbit and the Lord of the Rings',
#      'release_date': '2013-02-04',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5MBTOwS0yfq5hDhzRacsh2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oQJQUIpJFFnfKvHJA0xBu'},
#       'href': 'https://api.spotify.com/v1/artists/2oQJQUIpJFFnfKvHJA0xBu',
#       'id': '2oQJQUIpJFFnfKvHJA0xBu',
#       'name': 'The City of Prague Philharmonic Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oQJQUIpJFFnfKvHJA0xBu'}],
#     'disc_number': 1,
#     'duration_ms': 164106,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAJC0404550'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KqV8d7A86fiFWDTxWRXUI'},
#     'href': 'https://api.spotify.com/v1/tracks/1KqV8d7A86fiFWDTxWRXUI',
#     'id': '1KqV8d7A86fiFWDTxWRXUI',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2Twe7p278J2GxzjQZWJZWM'},
#      'href': 'https://api.spotify.com/v1/tracks/2Twe7p278J2GxzjQZWJZWM',
#      'id': '2Twe7p278J2GxzjQZWJZWM',
#      'type': 'track',
#      'uri': 'spotify:track:2Twe7p278J2GxzjQZWJZWM'},
#     'name': 'Concerning Hobbits (From "The Lord of the Rings: The Fellowship of the Ring")',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f08c3a271fc7321e2a032ed17689c063020ee0fa?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1KqV8d7A86fiFWDTxWRXUI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ohlPA8dRBtCf92zaZCaaB'},
#        'href': 'https://api.spotify.com/v1/artists/7ohlPA8dRBtCf92zaZCaaB',
#        'id': '7ohlPA8dRBtCf92zaZCaaB',
#        'name': 'Crowded House',
#        'type': 'artist',
#        'uri': 'spotify:artist:7ohlPA8dRBtCf92zaZCaaB'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6GStgagrrrhcj8p6WKjLdO'},
#      'href': 'https://api.spotify.com/v1/albums/6GStgagrrrhcj8p6WKjLdO',
#      'id': '6GStgagrrrhcj8p6WKjLdO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27375842f0e271b392b98fbb1c3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0275842f0e271b392b98fbb1c3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485175842f0e271b392b98fbb1c3',
#        'width': 64}],
#      'name': 'The Very Very Best Of Crowded House (Deluxe Edition)',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:6GStgagrrrhcj8p6WKjLdO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ohlPA8dRBtCf92zaZCaaB'},
#       'href': 'https://api.spotify.com/v1/artists/7ohlPA8dRBtCf92zaZCaaB',
#       'id': '7ohlPA8dRBtCf92zaZCaaB',
#       'name': 'Crowded House',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ohlPA8dRBtCf92zaZCaaB'}],
#     'disc_number': 2,
#     'duration_ms': 238362,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA28600048'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/68wIBE5dVVX8RyfZCJnAj5'},
#     'href': 'https://api.spotify.com/v1/tracks/68wIBE5dVVX8RyfZCJnAj5',
#     'id': '68wIBE5dVVX8RyfZCJnAj5',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Don't Dream It's Over",
#     'popularity': 42,
#     'preview_url': None,
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:68wIBE5dVVX8RyfZCJnAj5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iDD7bnsjL9J4fO298r0L0'},
#        'href': 'https://api.spotify.com/v1/artists/3iDD7bnsjL9J4fO298r0L0',
#        'id': '3iDD7bnsjL9J4fO298r0L0',
#        'name': 'Chicago',
#        'type': 'artist',
#        'uri': 'spotify:artist:3iDD7bnsjL9J4fO298r0L0'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4NmlDrnZOd3ejob9PoiOd9'},
#      'href': 'https://api.spotify.com/v1/albums/4NmlDrnZOd3ejob9PoiOd9',
#      'id': '4NmlDrnZOd3ejob9PoiOd9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef255849780dca4ccb991cbe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef255849780dca4ccb991cbe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef255849780dca4ccb991cbe',
#        'width': 64}],
#      'name': 'Chicago 16 (Expanded & Remastered)',
#      'release_date': '1982-06-07',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4NmlDrnZOd3ejob9PoiOd9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iDD7bnsjL9J4fO298r0L0'},
#       'href': 'https://api.spotify.com/v1/artists/3iDD7bnsjL9J4fO298r0L0',
#       'id': '3iDD7bnsjL9J4fO298r0L0',
#       'name': 'Chicago',
#       'type': 'artist',
#       'uri': 'spotify:artist:3iDD7bnsjL9J4fO298r0L0'}],
#     'disc_number': 1,
#     'duration_ms': 304213,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10603163'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/07TnWCHrFkvF61GzJuLVt0'},
#     'href': 'https://api.spotify.com/v1/tracks/07TnWCHrFkvF61GzJuLVt0',
#     'id': '07TnWCHrFkvF61GzJuLVt0',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Hard to Say I'm Sorry / Get Away - 2006 Remaster",
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ed072f2bc6fe0e0be670b1ee65a2705e5b726df5?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:07TnWCHrFkvF61GzJuLVt0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'disc_number': 1,
#     'duration_ms': 223346,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71614475'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/75ZvA4QfFiZvzhj2xkaWAh'},
#     'href': 'https://api.spotify.com/v1/tracks/75ZvA4QfFiZvzhj2xkaWAh',
#     'id': '75ZvA4QfFiZvzhj2xkaWAh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Fall Apart',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:75ZvA4QfFiZvzhj2xkaWAh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#        'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#        'id': '6oMuImdp5ZcFhWP0ESe6mG',
#        'name': 'Migos',
#        'type': 'artist',
#        'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2AvupjUeMnSffKEV05x222'},
#      'href': 'https://api.spotify.com/v1/albums/2AvupjUeMnSffKEV05x222',
#      'id': '2AvupjUeMnSffKEV05x222',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cf9b68115dcb2a222c252f00',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cf9b68115dcb2a222c252f00',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cf9b68115dcb2a222c252f00',
#        'width': 64}],
#      'name': 'Culture',
#      'release_date': '2017-04-07',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2AvupjUeMnSffKEV05x222'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#       'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#       'id': '6oMuImdp5ZcFhWP0ESe6mG',
#       'name': 'Migos',
#       'type': 'artist',
#       'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#     'disc_number': 1,
#     'duration_ms': 257545,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMCE31600875'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/76Y0gxtTxN0FyDCYh5qYQj'},
#     'href': 'https://api.spotify.com/v1/tracks/76Y0gxtTxN0FyDCYh5qYQj',
#     'id': '76Y0gxtTxN0FyDCYh5qYQj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Get Right Witcha',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/23ee7bc5d45b088bf38ba1736247a0ed4b72f449?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:76Y0gxtTxN0FyDCYh5qYQj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mDU6nMUJnOSY2Hkjz5oqM'},
#        'href': 'https://api.spotify.com/v1/artists/7mDU6nMUJnOSY2Hkjz5oqM',
#        'id': '7mDU6nMUJnOSY2Hkjz5oqM',
#        'name': 'Roy Woods',
#        'type': 'artist',
#        'uri': 'spotify:artist:7mDU6nMUJnOSY2Hkjz5oqM'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2vnPwMLtMXZWGkKsoylsGt'},
#      'href': 'https://api.spotify.com/v1/albums/2vnPwMLtMXZWGkKsoylsGt',
#      'id': '2vnPwMLtMXZWGkKsoylsGt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b2ad05eb1f89183231cde0e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b2ad05eb1f89183231cde0e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b2ad05eb1f89183231cde0e',
#        'width': 64}],
#      'name': 'Exis',
#      'release_date': '2015-07-31',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:2vnPwMLtMXZWGkKsoylsGt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mDU6nMUJnOSY2Hkjz5oqM'},
#       'href': 'https://api.spotify.com/v1/artists/7mDU6nMUJnOSY2Hkjz5oqM',
#       'id': '7mDU6nMUJnOSY2Hkjz5oqM',
#       'name': 'Roy Woods',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mDU6nMUJnOSY2Hkjz5oqM'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'disc_number': 1,
#     'duration_ms': 251859,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USWB11508706'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0PXp9QxBfSKGGpWUNaws2X'},
#     'href': 'https://api.spotify.com/v1/tracks/0PXp9QxBfSKGGpWUNaws2X',
#     'id': '0PXp9QxBfSKGGpWUNaws2X',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Drama (feat. Drake)',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4df2165563a663c285e8cdcb5069913d3fe838a2?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0PXp9QxBfSKGGpWUNaws2X'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#        'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#        'id': '1RyvyyTE3xzB2ZywiAwp0i',
#        'name': 'Future',
#        'type': 'artist',
#        'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0fUy6IdLHDpGNwavIlhEsl'},
#      'href': 'https://api.spotify.com/v1/albums/0fUy6IdLHDpGNwavIlhEsl',
#      'id': '0fUy6IdLHDpGNwavIlhEsl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b2592bea12d840fd096ef965',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b2592bea12d840fd096ef965',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b2592bea12d840fd096ef965',
#        'width': 64}],
#      'name': 'DS2 (Deluxe)',
#      'release_date': '2015-07-17',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:0fUy6IdLHDpGNwavIlhEsl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#       'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#       'id': '1RyvyyTE3xzB2ZywiAwp0i',
#       'name': 'Future',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#     'disc_number': 1,
#     'duration_ms': 237400,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM11500953'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/49zD0wr2S3d0lZPib0K4e1'},
#     'href': 'https://api.spotify.com/v1/tracks/49zD0wr2S3d0lZPib0K4e1',
#     'id': '49zD0wr2S3d0lZPib0K4e1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'F*ck Up Some Commas',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/374e7f17d3d4206d91557263c39396a5b2fc38fe?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:49zD0wr2S3d0lZPib0K4e1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'disc_number': 1,
#     'duration_ms': 237146,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71515989'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4SYUUlkScpNR1QvPscXf8t'},
#     'href': 'https://api.spotify.com/v1/tracks/4SYUUlkScpNR1QvPscXf8t',
#     'id': '4SYUUlkScpNR1QvPscXf8t',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Too Young',
#     'popularity': 68,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4SYUUlkScpNR1QvPscXf8t'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/17lzZA2AlOHwCwFALHttmp'},
#       'href': 'https://api.spotify.com/v1/artists/17lzZA2AlOHwCwFALHttmp',
#       'id': '17lzZA2AlOHwCwFALHttmp',
#       'name': '2 Chainz',
#       'type': 'artist',
#       'uri': 'spotify:artist:17lzZA2AlOHwCwFALHttmp'}],
#     'disc_number': 1,
#     'duration_ms': 224960,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71614473'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1ysAvOdJgUjc6CqOQxepaz'},
#     'href': 'https://api.spotify.com/v1/tracks/1ysAvOdJgUjc6CqOQxepaz',
#     'id': '1ysAvOdJgUjc6CqOQxepaz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Money Made Me Do It',
#     'popularity': 64,
#     'preview_url': None,
#     'track': True,
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:1ysAvOdJgUjc6CqOQxepaz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VRj0yCOv2FXJNP47XQnx5'},
#       'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#       'id': '0VRj0yCOv2FXJNP47XQnx5',
#       'name': 'Quavo',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'}],
#     'disc_number': 1,
#     'duration_ms': 220293,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71614484'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3a1lNhkSLSkpJE4MSHpDu9'},
#     'href': 'https://api.spotify.com/v1/tracks/3a1lNhkSLSkpJE4MSHpDu9',
#     'id': '3a1lNhkSLSkpJE4MSHpDu9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Congratulations',
#     'popularity': 84,
#     'preview_url': None,
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3a1lNhkSLSkpJE4MSHpDu9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'disc_number': 1,
#     'duration_ms': 219146,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71614492'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0LpiKjWMfZTkPPHonlM8nB'},
#     'href': 'https://api.spotify.com/v1/tracks/0LpiKjWMfZTkPPHonlM8nB',
#     'id': '0LpiKjWMfZTkPPHonlM8nB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Yours Truly, Austin Post',
#     'popularity': 62,
#     'preview_url': None,
#     'track': True,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:0LpiKjWMfZTkPPHonlM8nB'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'disc_number': 1,
#     'duration_ms': 234213,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71608604'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0H8XeaJunhvpBdBFIYi6Sh'},
#     'href': 'https://api.spotify.com/v1/tracks/0H8XeaJunhvpBdBFIYi6Sh',
#     'id': '0H8XeaJunhvpBdBFIYi6Sh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Deja Vu',
#     'popularity': 70,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0H8XeaJunhvpBdBFIYi6Sh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'disc_number': 1,
#     'duration_ms': 256533,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71511528'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6eT7xZZlB2mwyzJ2sUKG6w'},
#     'href': 'https://api.spotify.com/v1/tracks/6eT7xZZlB2mwyzJ2sUKG6w',
#     'id': '6eT7xZZlB2mwyzJ2sUKG6w',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'White Iverson',
#     'popularity': 78,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6eT7xZZlB2mwyzJ2sUKG6w'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#      'href': 'https://api.spotify.com/v1/albums/5s0rmjP8XOPhP6HhqOhuyC',
#      'id': '5s0rmjP8XOPhP6HhqOhuyC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355404f712deb84d0650a4b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255404f712deb84d0650a4b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155404f712deb84d0650a4b41',
#        'width': 64}],
#      'name': 'Stoney (Deluxe)',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:5s0rmjP8XOPhP6HhqOhuyC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'disc_number': 1,
#     'duration_ms': 324853,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71614496'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5dI1yHSqgmilFEqpGbqxHh'},
#     'href': 'https://api.spotify.com/v1/tracks/5dI1yHSqgmilFEqpGbqxHh',
#     'id': '5dI1yHSqgmilFEqpGbqxHh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Leave',
#     'popularity': 65,
#     'preview_url': None,
#     'track': True,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:5dI1yHSqgmilFEqpGbqxHh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
# ...
#        'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#        'id': '69GGBxA162lTqCwzJG5jLp',
#        'name': 'The Chainsmokers',
#        'type': 'artist',
#        'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64vx3cUb97lQGlgt8zozWL'},
#      'href': 'https://api.spotify.com/v1/albums/64vx3cUb97lQGlgt8zozWL',
#      'id': '64vx3cUb97lQGlgt8zozWL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e1b22ace42c98117458010b4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e1b22ace42c98117458010b4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e1b22ace42c98117458010b4',
#        'width': 64}],
#      'name': 'Paris',
#      'release_date': '2017-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:64vx3cUb97lQGlgt8zozWL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#       'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#       'id': '69GGBxA162lTqCwzJG5jLp',
#       'name': 'The Chainsmokers',
#       'type': 'artist',
#       'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'}],
#     'disc_number': 1,
#     'duration_ms': 221520,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91603031'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15vzANxN8G9wWfwAJLLMCg'},
#     'href': 'https://api.spotify.com/v1/tracks/15vzANxN8G9wWfwAJLLMCg',
#     'id': '15vzANxN8G9wWfwAJLLMCg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Paris',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2524797ca9b06a157f21199be68f0f0e94f71661?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:15vzANxN8G9wWfwAJLLMCg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0W5GGnapMz0VwemQvJDqa7'},
#      'href': 'https://api.spotify.com/v1/albums/0W5GGnapMz0VwemQvJDqa7',
#      'id': '0W5GGnapMz0VwemQvJDqa7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f0e911d0e5aadefc431bf34a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f0e911d0e5aadefc431bf34a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f0e911d0e5aadefc431bf34a',
#        'width': 64}],
#      'name': '+',
#      'release_date': '2011-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0W5GGnapMz0VwemQvJDqa7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 258373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1100095'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VdZ0vKfR5jneCmWIUAMxK'},
#     'href': 'https://api.spotify.com/v1/tracks/1VdZ0vKfR5jneCmWIUAMxK',
#     'id': '1VdZ0vKfR5jneCmWIUAMxK',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The A Team',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37bf226e93591d438dde11e6404e3751a108084f?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1VdZ0vKfR5jneCmWIUAMxK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#        'width': 64}],
#      'name': '÷ (Deluxe)',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 233712,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1600463'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3'},
#     'href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#     'id': '7qiZfU4dY1lWllzX7mPBI3',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0FE9t6xYkqWXU2ahLh6D8X'},
#      'href': 'https://api.spotify.com/v1/tracks/0FE9t6xYkqWXU2ahLh6D8X',
#      'id': '0FE9t6xYkqWXU2ahLh6D8X',
#      'type': 'track',
#      'uri': 'spotify:track:0FE9t6xYkqWXU2ahLh6D8X'},
#     'name': 'Shape of You',
#     'popularity': 88,
#     'preview_url': 'https://p.scdn.co/mp3-preview/84462d8e1e4d0f9e5ccd06f0da390f65843774a2?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#        'width': 64}],
#      'name': '÷ (Deluxe)',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 261153,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1600462'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6PCUP3dWmTjcTtXY02oFdT'},
#     'href': 'https://api.spotify.com/v1/tracks/6PCUP3dWmTjcTtXY02oFdT',
#     'id': '6PCUP3dWmTjcTtXY02oFdT',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/66qlqxhEMpSHOzjRK4il0b'},
#      'href': 'https://api.spotify.com/v1/tracks/66qlqxhEMpSHOzjRK4il0b',
#      'id': '66qlqxhEMpSHOzjRK4il0b',
#      'type': 'track',
#      'uri': 'spotify:track:66qlqxhEMpSHOzjRK4il0b'},
#     'name': 'Castle on the Hill',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/beb4ed48cca5d2a792e877c7efe92d54046eac67?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6PCUP3dWmTjcTtXY02oFdT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6pZj4nvx6lV3ulIK3BSjvs'},
#      'href': 'https://api.spotify.com/v1/albums/6pZj4nvx6lV3ulIK3BSjvs',
#      'id': '6pZj4nvx6lV3ulIK3BSjvs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733505183cc0e24d2f7560174a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023505183cc0e24d2f7560174a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513505183cc0e24d2f7560174a',
#        'width': 64}],
#      'name': 'Moana (Original Motion Picture Soundtrack/Deluxe Edition)',
#      'release_date': '2016-11-18',
#      'release_date_precision': 'day',
#      'total_tracks': 59,
#      'type': 'album',
#      'uri': 'spotify:album:6pZj4nvx6lV3ulIK3BSjvs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5mnS9jJdKQQcRSqFu5YPVe'},
#       'href': 'https://api.spotify.com/v1/artists/5mnS9jJdKQQcRSqFu5YPVe',
#       'id': '5mnS9jJdKQQcRSqFu5YPVe',
#       'name': "Auli'i Cravalho",
#       'type': 'artist',
#       'uri': 'spotify:artist:5mnS9jJdKQQcRSqFu5YPVe'}],
#     'disc_number': 1,
#     'duration_ms': 163386,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11677855'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6mb6lVLNrcUgLnEN8QnDJd'},
#     'href': 'https://api.spotify.com/v1/tracks/6mb6lVLNrcUgLnEN8QnDJd',
#     'id': '6mb6lVLNrcUgLnEN8QnDJd',
#     'is_local': False,
#     'is_playable': True,
#     'name': "How Far I'll Go",
#     'popularity': 76,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6mb6lVLNrcUgLnEN8QnDJd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-04-25T00:14:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1237826676'},
#     'href': 'https://api.spotify.com/v1/users/1237826676',
#     'id': '1237826676',
#     'type': 'user',
#     'uri': 'spotify:user:1237826676'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15iVAtD3s3FsQR4w1v6M0P'},
#        'href': 'https://api.spotify.com/v1/artists/15iVAtD3s3FsQR4w1v6M0P',
#        'id': '15iVAtD3s3FsQR4w1v6M0P',
#        'name': 'Chief Keef',
#        'type': 'artist',
#        'uri': 'spotify:artist:15iVAtD3s3FsQR4w1v6M0P'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2B4y3j02ho6XNF8BEzx3JF'},
#      'href': 'https://api.spotify.com/v1/albums/2B4y3j02ho6XNF8BEzx3JF',
#      'id': '2B4y3j02ho6XNF8BEzx3JF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a76616abf60ce17491e95891',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a76616abf60ce17491e95891',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a76616abf60ce17491e95891',
#        'width': 64}],
#      'name': 'Finally Rich',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2B4y3j02ho6XNF8BEzx3JF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15iVAtD3s3FsQR4w1v6M0P'},
#       'href': 'https://api.spotify.com/v1/artists/15iVAtD3s3FsQR4w1v6M0P',
#       'id': '15iVAtD3s3FsQR4w1v6M0P',
#       'name': 'Chief Keef',
#       'type': 'artist',
#       'uri': 'spotify:artist:15iVAtD3s3FsQR4w1v6M0P'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bPxKZtCdjB1aj1csBJpdS'},
#       'href': 'https://api.spotify.com/v1/artists/1bPxKZtCdjB1aj1csBJpdS',
#       'id': '1bPxKZtCdjB1aj1csBJpdS',
#       'name': 'Lil Reese',
#       'type': 'artist',
#       'uri': 'spotify:artist:1bPxKZtCdjB1aj1csBJpdS'}],
#     'disc_number': 1,
#     'duration_ms': 293840,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71207543'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1h6kgem1ai8vUgO1rZOwfB'},
#     'href': 'https://api.spotify.com/v1/tracks/1h6kgem1ai8vUgO1rZOwfB',
#     'id': '1h6kgem1ai8vUgO1rZOwfB',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2ikkgfIIM9kGKZCXzXnTpj'},
#      'href': 'https://api.spotify.com/v1/tracks/2ikkgfIIM9kGKZCXzXnTpj',
#      'id': '2ikkgfIIM9kGKZCXzXnTpj',
#      'type': 'track',
#      'uri': 'spotify:track:2ikkgfIIM9kGKZCXzXnTpj'},
#     'name': "I Don't Like",
#     'popularity': 69,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1h6kgem1ai8vUgO1rZOwfB'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/1Ien12ACUL1Q2V2xIra3WO/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 9521}

# %%
track_list = get_playlist_tracks("spotify", "1Ien12ACUL1Q2V2xIra3WO")

# %%
track_list[0]['track']['id']
# Out:
# '2pTW1GkqQ6dPTBOff2ZqQc'

# %%
list_of_songs=[]
for index in range(1,len(track_list)):
    list_of_songs.append(sp.audio_features(track_list[index]["track"]["id"])[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pp/zj2l4jcx48v20ggrz_hy7wdr0000gn/T/ipykernel_35529/626615404.py in <module>
#       1 list_of_songs=[]
#       2 for index in range(1,len(track_list)):
# ----> 3     list_of_songs.append(sp.audio_features(track_list[index]["track"]["id"])[0])
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/spotipy/client.py in audio_features(self, tracks)
#    1680             results = self._get("audio-features/?ids=" + trackid)
#    1681         else:
# -> 1682             tlist = [self._get_id("track", t) for t in tracks]
#    1683             results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1684         # the response has changed, look for the new style first, and if
#
# TypeError: 'NoneType' object is not iterable

# %%
list_of_songs_cleaned =[]

for i in list_of_songs:
    
    if i is None:
        pass
    else:
        list_of_songs_cleaned.append(i)

# %%
len(list_of_songs_cleaned)

# %%
song_df = pd.DataFrame(list_of_songs_cleaned)
