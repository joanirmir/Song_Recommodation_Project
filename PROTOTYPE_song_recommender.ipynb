# %%
from IPython.display import IFrame

import songRecommenderProjectUtils as proj_utils
## allow output of multiple values per cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

# %%
proj_utils.cluster_feature_heatmap()

# %%
usertrack, rectrack = proj_utils.run_recommender()
usertrack
rectrack
# Out:
# enter song name: apricots
# Enter 0 for 'Apricots' by 'Bicep'
# Enter 1 for 'Apricots' by 'Bicep'
# Enter 2 for 'Apricots' by 'MAY-A'
# Enter 3 for 'Apricots' by 'Diet Cig'
# Enter 4 for 'Apricots (Private Playlist) [WYM341]' by 'Bicep'
# Enter 5 for 'Apricots (Naked)' by 'MAY-A'
# Enter 6 for 'Apricots' by 'Bicep'
# Enter 7 for 'Apricots' by 'MAY-A'
# Enter 8 for 'Apricots - Original Mix' by 'HNNY'
# Enter 9 for 'Apricots - (Mixed)' by 'Solarity'
# Enter [SPACE] for 'None of the above'
# 0
# Based on the track:
# 	Apricots
# 	by Bicep
#
# I recommend SIMILAR song:
# (Genre 4 - Longer duration & highly instrumental (4,329 tracks))
# 	Running Wild (feat. The Oddictions and Britt Daley) - Jayceeoh Remix
# 	by Morgan Page / Jayceeoh / The Oddictions / Britt Daley
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0WfOuXw05LJq4ik1lVvTzi?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2ytQKZdKX7cBmTVUyMOpDh?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
