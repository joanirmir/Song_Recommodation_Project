# %%
import config

# %%
c_id = config.c_id

# %%
c_se = config.c_se

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= c_id,
                                                           client_secret= c_se))

# %%
playlist = sp.user_playlist_tracks("spotify", "51waoWnTP4bkSOCrBYH3Uv",market="GB")

# %%
print(list(playlist.keys()))
print("Total number of songs in the playlist: ",playlist["total"])
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  416
# 100

# %%
## Using this function
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
len(get_playlist_tracks("spotify", "51waoWnTP4bkSOCrBYH3Uv"))
# Out:
# 416

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/51waoWnTP4bkSOCrBYH3Uv/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2018-12-25T19:58:14Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/grkomasibiqjpeprqxeimx55s'},
#     'href': 'https://api.spotify.com/v1/users/grkomasibiqjpeprqxeimx55s',
#     'id': 'grkomasibiqjpeprqxeimx55s',
#     'type': 'user',
#     'uri': 'spotify:user:grkomasibiqjpeprqxeimx55s'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V1qsQHdXNm4ZEZHWvFnqQ'},
#        'href': 'https://api.spotify.com/v1/artists/5V1qsQHdXNm4ZEZHWvFnqQ',
#        'id': '5V1qsQHdXNm4ZEZHWvFnqQ',
#        'name': 'Dreamcatcher',
#        'type': 'artist',
#        'uri': 'spotify:artist:5V1qsQHdXNm4ZEZHWvFnqQ'}],
# ...

# %%
track_list = get_playlist_tracks("spotify", "51waoWnTP4bkSOCrBYH3Uv")

# %%
track_list[0]['track']['id']
# Out:
# '4aDLGyls7Qzv2xMISvDZV4'

# %%
list_of_songs=[]
for index in range(1,len(track_list)):
    list_of_songs.append(sp.audio_features(track_list[index]["track"]["id"])[0])

# %%
song_df = pd.DataFrame(list_of_songs)

# %%
song_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.785   0.744    3    -4.249     0       0.0369       0.01490
# 1           0.725   0.940    5    -2.320     0       0.0435       0.11500
# 2           0.602   0.658    1    -5.934     1       0.0558       0.02330
# 3           0.592   0.788    6    -4.924     0       0.2010       0.05990
# 4           0.641   0.837    4    -3.356     1       0.3680       0.04810
# ..            ...     ...  ...       ...   ...          ...           ...
# 410         0.594   0.874    5    -3.598     1       0.0387       0.00166
# 411         0.473   0.657    6    -6.278     1       0.0240       0.04540
# 412         0.541   0.769    4    -6.253     1       0.0339       0.05560
# 413         0.671   0.782    7    -6.498     1       0.0470       0.01220
# 414         0.464   0.775    7    -4.838     1       0.0313       0.20300
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
song_df.to_csv('KpopIndieMpbPopRap_416.csv', index = False)

# %%
list_of_songs_cleaned =[]

for i in list_of_songs:
    
    if i is None:
        pass
    else:
        list_of_songs_cleaned.append(i)

# %%
len(list_of_songs_cleaned)

# %%
song_df = pd.DataFrame(list_of_songs_cleaned)
