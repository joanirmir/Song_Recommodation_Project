# %%
import config

# %%
c_id = config.c_id

# %%
c_se = config.c_se

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= c_id,
                                                           client_secret= c_se))

# %%
playlist = sp.user_playlist_tracks("spotify", "1TZPvlws7CjSHpXgHGEoMG",market="GB")

# %%
print(list(playlist.keys()))
print("Total number of songs in the playlist: ",playlist["total"])
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  444
# 100

# %%
## Using this function
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
len(get_playlist_tracks("spotify", "1TZPvlws7CjSHpXgHGEoMG"))
# Out:
# 444

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1TZPvlws7CjSHpXgHGEoMG/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1btv9qmIpbp7q1ixCYNdHu'},
#        'href': 'https://api.spotify.com/v1/artists/1btv9qmIpbp7q1ixCYNdHu',
#        'id': '1btv9qmIpbp7q1ixCYNdHu',
#        'name': 'Adam Beyer',
#        'type': 'artist',
#        'uri': 'spotify:artist:1btv9qmIpbp7q1ixCYNdHu'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1k7wSrUVVEIsmxGeGODqrP'},
#      'href': 'https://api.spotify.com/v1/albums/1k7wSrUVVEIsmxGeGODqrP',
#      'id': '1k7wSrUVVEIsmxGeGODqrP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27358ecc53446a25c1f9264c520',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0258ecc53446a25c1f9264c520',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485158ecc53446a25c1f9264c520',
#        'width': 64}],
#      'name': 'Teach Me',
#      'release_date': '2014-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:1k7wSrUVVEIsmxGeGODqrP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1btv9qmIpbp7q1ixCYNdHu'},
#       'href': 'https://api.spotify.com/v1/artists/1btv9qmIpbp7q1ixCYNdHu',
#       'id': '1btv9qmIpbp7q1ixCYNdHu',
#       'name': 'Adam Beyer',
#       'type': 'artist',
#       'uri': 'spotify:artist:1btv9qmIpbp7q1ixCYNdHu'}],
#     'disc_number': 1,
#     'duration_ms': 594814,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUR61200253'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5rqRPLVqce2Cju2ytq59xu'},
#     'href': 'https://api.spotify.com/v1/tracks/5rqRPLVqce2Cju2ytq59xu',
#     'id': '5rqRPLVqce2Cju2ytq59xu',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Teach Me',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5453c86e25cd3d88829ead64670bc3f92a55c48c?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5rqRPLVqce2Cju2ytq59xu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-07-05T10:46:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#        'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#        'id': '3hteYQFiMFbJY7wS0xDymP',
#        'name': 'Gesaffelstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3MiiF9utmtGnLVITgl0JP7'},
#      'href': 'https://api.spotify.com/v1/albums/3MiiF9utmtGnLVITgl0JP7',
#      'id': '3MiiF9utmtGnLVITgl0JP7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731de5e87e7deee835774de29c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021de5e87e7deee835774de29c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511de5e87e7deee835774de29c',
#        'width': 64}],
#      'name': 'Aleph',
#      'release_date': '2013-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3MiiF9utmtGnLVITgl0JP7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#       'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#       'id': '3hteYQFiMFbJY7wS0xDymP',
#       'name': 'Gesaffelstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#     'disc_number': 1,
#     'duration_ms': 216720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ111300566'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Ub5SzOZ2kGwoazjnQSfdS'},
#     'href': 'https://api.spotify.com/v1/tracks/5Ub5SzOZ2kGwoazjnQSfdS',
#     'id': '5Ub5SzOZ2kGwoazjnQSfdS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Destinations',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9e00b5326f7782b3f81583bfd42d5ae4e655d94d?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5Ub5SzOZ2kGwoazjnQSfdS'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hini2nQyoglzpdKe41cZt'},
#        'href': 'https://api.spotify.com/v1/artists/5Hini2nQyoglzpdKe41cZt',
#        'id': '5Hini2nQyoglzpdKe41cZt',
#        'name': 'UMEK',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Hini2nQyoglzpdKe41cZt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1vw83Vkol2QTFeILo2wqUX'},
#      'href': 'https://api.spotify.com/v1/albums/1vw83Vkol2QTFeILo2wqUX',
#      'id': '1vw83Vkol2QTFeILo2wqUX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27328f1df15456fb8ed2df4fddd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0228f1df15456fb8ed2df4fddd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485128f1df15456fb8ed2df4fddd',
#        'width': 64}],
#      'name': 'Vigilance EP',
#      'release_date': '2019-10-18',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1vw83Vkol2QTFeILo2wqUX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hini2nQyoglzpdKe41cZt'},
#       'href': 'https://api.spotify.com/v1/artists/5Hini2nQyoglzpdKe41cZt',
#       'id': '5Hini2nQyoglzpdKe41cZt',
#       'name': 'UMEK',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Hini2nQyoglzpdKe41cZt'}],
#     'disc_number': 1,
#     'duration_ms': 399566,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SIB151900010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0P0rTrGkQMCei95omAOdQq'},
#     'href': 'https://api.spotify.com/v1/tracks/0P0rTrGkQMCei95omAOdQq',
#     'id': '0P0rTrGkQMCei95omAOdQq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Vigilance - Original Mix',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4cf314177bdf0052c4615a103912e959bc883720?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0P0rTrGkQMCei95omAOdQq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1btv9qmIpbp7q1ixCYNdHu'},
#        'href': 'https://api.spotify.com/v1/artists/1btv9qmIpbp7q1ixCYNdHu',
#        'id': '1btv9qmIpbp7q1ixCYNdHu',
#        'name': 'Adam Beyer',
#        'type': 'artist',
#        'uri': 'spotify:artist:1btv9qmIpbp7q1ixCYNdHu'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0rR2VfpjlsH2mCYaoeXtRo'},
#      'href': 'https://api.spotify.com/v1/albums/0rR2VfpjlsH2mCYaoeXtRo',
#      'id': '0rR2VfpjlsH2mCYaoeXtRo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273acf732cc56b447b895938ab6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02acf732cc56b447b895938ab6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851acf732cc56b447b895938ab6',
#        'width': 64}],
#      'name': 'Stone Flower',
#      'release_date': '2015-05-18',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:0rR2VfpjlsH2mCYaoeXtRo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1btv9qmIpbp7q1ixCYNdHu'},
#       'href': 'https://api.spotify.com/v1/artists/1btv9qmIpbp7q1ixCYNdHu',
#       'id': '1btv9qmIpbp7q1ixCYNdHu',
#       'name': 'Adam Beyer',
#       'type': 'artist',
#       'uri': 'spotify:artist:1btv9qmIpbp7q1ixCYNdHu'}],
#     'disc_number': 1,
#     'duration_ms': 401150,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUR61500041'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Bwy2Bwxqzhx8bfSBgWY5W'},
#     'href': 'https://api.spotify.com/v1/tracks/0Bwy2Bwxqzhx8bfSBgWY5W',
#     'id': '0Bwy2Bwxqzhx8bfSBgWY5W',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'What You Need',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c7f276fcab3af3a56065bcc6341de5b00a77134f?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0Bwy2Bwxqzhx8bfSBgWY5W'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-07-05T10:46:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#        'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#        'id': '3hteYQFiMFbJY7wS0xDymP',
#        'name': 'Gesaffelstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3MiiF9utmtGnLVITgl0JP7'},
#      'href': 'https://api.spotify.com/v1/albums/3MiiF9utmtGnLVITgl0JP7',
#      'id': '3MiiF9utmtGnLVITgl0JP7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731de5e87e7deee835774de29c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021de5e87e7deee835774de29c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511de5e87e7deee835774de29c',
#        'width': 64}],
#      'name': 'Aleph',
#      'release_date': '2013-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3MiiF9utmtGnLVITgl0JP7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#       'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#       'id': '3hteYQFiMFbJY7wS0xDymP',
#       'name': 'Gesaffelstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#     'disc_number': 1,
#     'duration_ms': 309880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ111300568'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0mA1O0OQJPdY6eeMRWh5tj'},
#     'href': 'https://api.spotify.com/v1/tracks/0mA1O0OQJPdY6eeMRWh5tj',
#     'id': '0mA1O0OQJPdY6eeMRWh5tj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Piece of Future',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4af5359acbc278c76724625bf24c0de9e5d0a614?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0mA1O0OQJPdY6eeMRWh5tj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:47:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#        'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#        'id': '0KyUH5WmspOhuIQAnw42Fb',
#        'name': 'Paranoid London',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59Oocb38BCohi63wnSnrcU'},
#      'href': 'https://api.spotify.com/v1/albums/59Oocb38BCohi63wnSnrcU',
#      'id': '59Oocb38BCohi63wnSnrcU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c5f7ff4b8c920d427fedf9a6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c5f7ff4b8c920d427fedf9a6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c5f7ff4b8c920d427fedf9a6',
#        'width': 64}],
#      'name': 'PL',
#      'release_date': '2019-08-30',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:59Oocb38BCohi63wnSnrcU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#       'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#       'id': '0KyUH5WmspOhuIQAnw42Fb',
#       'name': 'Paranoid London',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0SFzGc8fvOuNpikX5mMP4t'},
#       'href': 'https://api.spotify.com/v1/artists/0SFzGc8fvOuNpikX5mMP4t',
#       'id': '0SFzGc8fvOuNpikX5mMP4t',
#       'name': 'Mutado Pintado',
#       'type': 'artist',
#       'uri': 'spotify:artist:0SFzGc8fvOuNpikX5mMP4t'}],
#     'disc_number': 1,
#     'duration_ms': 441215,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKA481900014'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4AY2YP9aW88V2IOSuFaWQt'},
#     'href': 'https://api.spotify.com/v1/tracks/4AY2YP9aW88V2IOSuFaWQt',
#     'id': '4AY2YP9aW88V2IOSuFaWQt',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Just My Size',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c7578315cd169262ff5675eaac21c14b78ed2f60?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4AY2YP9aW88V2IOSuFaWQt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-07-05T10:46:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#        'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#        'id': '3hteYQFiMFbJY7wS0xDymP',
#        'name': 'Gesaffelstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3MiiF9utmtGnLVITgl0JP7'},
#      'href': 'https://api.spotify.com/v1/albums/3MiiF9utmtGnLVITgl0JP7',
#      'id': '3MiiF9utmtGnLVITgl0JP7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731de5e87e7deee835774de29c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021de5e87e7deee835774de29c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511de5e87e7deee835774de29c',
#        'width': 64}],
#      'name': 'Aleph',
#      'release_date': '2013-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3MiiF9utmtGnLVITgl0JP7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#       'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#       'id': '3hteYQFiMFbJY7wS0xDymP',
#       'name': 'Gesaffelstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#     'disc_number': 1,
#     'duration_ms': 214226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ111300560'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3mmzcFxcFIPT3H9DRfuEs3'},
#     'href': 'https://api.spotify.com/v1/tracks/3mmzcFxcFIPT3H9DRfuEs3',
#     'id': '3mmzcFxcFIPT3H9DRfuEs3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfection',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b617153fbd2be730525cfff1c777052139dc9eb2?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:3mmzcFxcFIPT3H9DRfuEs3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kR99O4MgSTasyeJh8UFCg'},
#        'href': 'https://api.spotify.com/v1/artists/1kR99O4MgSTasyeJh8UFCg',
#        'id': '1kR99O4MgSTasyeJh8UFCg',
#        'name': 'DJ Koze',
#        'type': 'artist',
#        'uri': 'spotify:artist:1kR99O4MgSTasyeJh8UFCg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7awbcJCFjNCtuzgEyPNFbB'},
#      'href': 'https://api.spotify.com/v1/albums/7awbcJCFjNCtuzgEyPNFbB',
#      'id': '7awbcJCFjNCtuzgEyPNFbB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27343e1c8254d1894b6a603a303',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0243e1c8254d1894b6a603a303',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485143e1c8254d1894b6a603a303',
#        'width': 64}],
#      'name': 'XTC',
#      'release_date': '2015-06-15',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7awbcJCFjNCtuzgEyPNFbB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kR99O4MgSTasyeJh8UFCg'},
#       'href': 'https://api.spotify.com/v1/artists/1kR99O4MgSTasyeJh8UFCg',
#       'id': '1kR99O4MgSTasyeJh8UFCg',
#       'name': 'DJ Koze',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kR99O4MgSTasyeJh8UFCg'}],
#     'disc_number': 1,
#     'duration_ms': 499258,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEMM11500007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1wYg1Ud13bBAJgKocnm73h'},
#     'href': 'https://api.spotify.com/v1/tracks/1wYg1Ud13bBAJgKocnm73h',
#     'id': '1wYg1Ud13bBAJgKocnm73h',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4n1oM7Ng15NuPyDyWRNOKM'},
#      'href': 'https://api.spotify.com/v1/tracks/4n1oM7Ng15NuPyDyWRNOKM',
#      'id': '4n1oM7Ng15NuPyDyWRNOKM',
#      'type': 'track',
#      'uri': 'spotify:track:4n1oM7Ng15NuPyDyWRNOKM'},
#     'name': 'XTC',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b1b2db32b5116984068b2d071393946a4a83f882?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1wYg1Ud13bBAJgKocnm73h'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KYGpc3Hn1KG7uw7CxQB2y'},
#        'href': 'https://api.spotify.com/v1/artists/2KYGpc3Hn1KG7uw7CxQB2y',
#        'id': '2KYGpc3Hn1KG7uw7CxQB2y',
#        'name': 'MATRiXXMAN',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KYGpc3Hn1KG7uw7CxQB2y'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0h154IoHceoxecVBZSopbt'},
#        'href': 'https://api.spotify.com/v1/artists/0h154IoHceoxecVBZSopbt',
#        'id': '0h154IoHceoxecVBZSopbt',
#        'name': 'Bauernfeind',
#        'type': 'artist',
#        'uri': 'spotify:artist:0h154IoHceoxecVBZSopbt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3oY55u52I3mAx3YESo327t'},
#      'href': 'https://api.spotify.com/v1/albums/3oY55u52I3mAx3YESo327t',
#      'id': '3oY55u52I3mAx3YESo327t',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f9b12d597e4653dfa21e212',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f9b12d597e4653dfa21e212',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f9b12d597e4653dfa21e212',
#        'width': 64}],
#      'name': 'No Rush',
#      'release_date': '2019-01-25',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:3oY55u52I3mAx3YESo327t'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KYGpc3Hn1KG7uw7CxQB2y'},
#       'href': 'https://api.spotify.com/v1/artists/2KYGpc3Hn1KG7uw7CxQB2y',
#       'id': '2KYGpc3Hn1KG7uw7CxQB2y',
#       'name': 'MATRiXXMAN',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KYGpc3Hn1KG7uw7CxQB2y'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0h154IoHceoxecVBZSopbt'},
#       'href': 'https://api.spotify.com/v1/artists/0h154IoHceoxecVBZSopbt',
#       'id': '0h154IoHceoxecVBZSopbt',
#       'name': 'Bauernfeind',
#       'type': 'artist',
#       'uri': 'spotify:artist:0h154IoHceoxecVBZSopbt'}],
#     'disc_number': 1,
#     'duration_ms': 374955,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEU671900325'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6NSn9RY41gzEO13SCTXs5k'},
#     'href': 'https://api.spotify.com/v1/tracks/6NSn9RY41gzEO13SCTXs5k',
#     'id': '6NSn9RY41gzEO13SCTXs5k',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'No Rush',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/067c55fe735c2a8dcf4e075699966f2b4c9664a5?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6NSn9RY41gzEO13SCTXs5k'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-07-05T10:46:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#        'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#        'id': '3hteYQFiMFbJY7wS0xDymP',
#        'name': 'Gesaffelstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3WSHoNpx7QQMcmfm26wksh'},
#      'href': 'https://api.spotify.com/v1/albums/3WSHoNpx7QQMcmfm26wksh',
#      'id': '3WSHoNpx7QQMcmfm26wksh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735ae330fa9f5dec1731fe3362',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025ae330fa9f5dec1731fe3362',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515ae330fa9f5dec1731fe3362',
#        'width': 64}],
#      'name': 'Conspiracy Pt.2',
#      'release_date': '2011-07-18',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:3WSHoNpx7QQMcmfm26wksh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#       'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#       'id': '3hteYQFiMFbJY7wS0xDymP',
#       'name': 'Gesaffelstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#     'disc_number': 1,
#     'duration_ms': 150200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAT391100127'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3rGfD8XpNBkv3WOgHPROiS'},
#     'href': 'https://api.spotify.com/v1/tracks/3rGfD8XpNBkv3WOgHPROiS',
#     'id': '3rGfD8XpNBkv3WOgHPROiS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Conspiracy Origins',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a844538d10e437e3af90d0f1e006ee2b8ac83c66?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3rGfD8XpNBkv3WOgHPROiS'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lJoRDjlvFXZLvSRVeM6m8'},
#        'href': 'https://api.spotify.com/v1/artists/3lJoRDjlvFXZLvSRVeM6m8',
#        'id': '3lJoRDjlvFXZLvSRVeM6m8',
#        'name': 'Chlär',
#        'type': 'artist',
#        'uri': 'spotify:artist:3lJoRDjlvFXZLvSRVeM6m8'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2bxHKwXosSU2aDK6GY5Tgw'},
#      'href': 'https://api.spotify.com/v1/albums/2bxHKwXosSU2aDK6GY5Tgw',
#      'id': '2bxHKwXosSU2aDK6GY5Tgw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27399c9254f6c38dda860db6069',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0299c9254f6c38dda860db6069',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485199c9254f6c38dda860db6069',
#        'width': 64}],
#      'name': 'Sacrificed Generation',
#      'release_date': '2021-06-11',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:2bxHKwXosSU2aDK6GY5Tgw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lJoRDjlvFXZLvSRVeM6m8'},
#       'href': 'https://api.spotify.com/v1/artists/3lJoRDjlvFXZLvSRVeM6m8',
#       'id': '3lJoRDjlvFXZLvSRVeM6m8',
#       'name': 'Chlär',
#       'type': 'artist',
#       'uri': 'spotify:artist:3lJoRDjlvFXZLvSRVeM6m8'}],
#     'disc_number': 1,
#     'duration_ms': 409510,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKN6K2002788'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6VOQLOIJTGnAGmn1q3QZrb'},
#     'href': 'https://api.spotify.com/v1/tracks/6VOQLOIJTGnAGmn1q3QZrb',
#     'id': '6VOQLOIJTGnAGmn1q3QZrb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Forgot to Dream',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/18a3de518c911f6286effb95baf32b006d3709d6?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6VOQLOIJTGnAGmn1q3QZrb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qGp6i03fQolBNPswoWKMV'},
#        'href': 'https://api.spotify.com/v1/artists/1qGp6i03fQolBNPswoWKMV',
#        'id': '1qGp6i03fQolBNPswoWKMV',
#        'name': 'Hush & Sleep',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qGp6i03fQolBNPswoWKMV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/26qvZFXxZU6O1sDlONmkWk'},
#      'href': 'https://api.spotify.com/v1/albums/26qvZFXxZU6O1sDlONmkWk',
#      'id': '26qvZFXxZU6O1sDlONmkWk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f7dc7008d6599ee63141868c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f7dc7008d6599ee63141868c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f7dc7008d6599ee63141868c',
#        'width': 64}],
#      'name': 'Emozione',
#      'release_date': '2020-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:26qvZFXxZU6O1sDlONmkWk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qGp6i03fQolBNPswoWKMV'},
#       'href': 'https://api.spotify.com/v1/artists/1qGp6i03fQolBNPswoWKMV',
#       'id': '1qGp6i03fQolBNPswoWKMV',
#       'name': 'Hush & Sleep',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qGp6i03fQolBNPswoWKMV'}],
#     'disc_number': 1,
#     'duration_ms': 378606,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DECY52002648'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3R0YwPNVsYY225eUBGUP3W'},
#     'href': 'https://api.spotify.com/v1/tracks/3R0YwPNVsYY225eUBGUP3W',
#     'id': '3R0YwPNVsYY225eUBGUP3W',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Emozione',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8b8adcad723458d919375e12e86a37eec7a17b9b?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3R0YwPNVsYY225eUBGUP3W'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5fRLZv6y9o3YZZNv6zk3DV'},
#      'href': 'https://api.spotify.com/v1/albums/5fRLZv6y9o3YZZNv6zk3DV',
#      'id': '5fRLZv6y9o3YZZNv6zk3DV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27356f4c0b09078801013d57478',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0256f4c0b09078801013d57478',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485156f4c0b09078801013d57478',
#        'width': 64}],
#      'name': 'Exhale VA002',
#      'release_date': '2021-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5fRLZv6y9o3YZZNv6zk3DV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uD2LjPHUjxrpax0se17Nc'},
#       'href': 'https://api.spotify.com/v1/artists/6uD2LjPHUjxrpax0se17Nc',
#       'id': '6uD2LjPHUjxrpax0se17Nc',
#       'name': '999999999',
#       'type': 'artist',
#       'uri': 'spotify:artist:6uD2LjPHUjxrpax0se17Nc'}],
#     'disc_number': 1,
#     'duration_ms': 285307,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BEN582100278'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2PJzDaYy7vPGpYaLFD7uQ6'},
#     'href': 'https://api.spotify.com/v1/tracks/2PJzDaYy7vPGpYaLFD7uQ6',
#     'id': '2PJzDaYy7vPGpYaLFD7uQ6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Alarm 303',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8d2f4682bc8a234429b0dcc4aeda9c6ea72ea24a?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2PJzDaYy7vPGpYaLFD7uQ6'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:47:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#        'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#        'id': '0KyUH5WmspOhuIQAnw42Fb',
#        'name': 'Paranoid London',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0wdxdBlbsDLeAYpDofB1NU'},
#      'href': 'https://api.spotify.com/v1/albums/0wdxdBlbsDLeAYpDofB1NU',
#      'id': '0wdxdBlbsDLeAYpDofB1NU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273be14e38280e7a0d113fd9acb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02be14e38280e7a0d113fd9acb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851be14e38280e7a0d113fd9acb',
#        'width': 64}],
#      'name': 'Paranoid London',
#      'release_date': '2018-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0wdxdBlbsDLeAYpDofB1NU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#       'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#       'id': '0KyUH5WmspOhuIQAnw42Fb',
#       'name': 'Paranoid London',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#     'disc_number': 1,
#     'duration_ms': 340320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKA481500017'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/482gLoC19yWptV2sUhcH3O'},
#     'href': 'https://api.spotify.com/v1/tracks/482gLoC19yWptV2sUhcH3O',
#     'id': '482gLoC19yWptV2sUhcH3O',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Headtrack',
#     'popularity': 18,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4d342167826459414aeca4bed7dc0b4b79ffa774?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:482gLoC19yWptV2sUhcH3O'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-07-05T10:46:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#        'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#        'id': '3hteYQFiMFbJY7wS0xDymP',
#        'name': 'Gesaffelstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3MiiF9utmtGnLVITgl0JP7'},
#      'href': 'https://api.spotify.com/v1/albums/3MiiF9utmtGnLVITgl0JP7',
#      'id': '3MiiF9utmtGnLVITgl0JP7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731de5e87e7deee835774de29c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021de5e87e7deee835774de29c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511de5e87e7deee835774de29c',
#        'width': 64}],
#      'name': 'Aleph',
#      'release_date': '2013-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3MiiF9utmtGnLVITgl0JP7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#       'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#       'id': '3hteYQFiMFbJY7wS0xDymP',
#       'name': 'Gesaffelstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#     'disc_number': 1,
#     'duration_ms': 247603,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ111300412'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2jJIxT6WAIVWzDo3Ou53Q0'},
#     'href': 'https://api.spotify.com/v1/tracks/2jJIxT6WAIVWzDo3Ou53Q0',
#     'id': '2jJIxT6WAIVWzDo3Ou53Q0',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Pursuit',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5feb286435a3a4b03cb890c3678291888d4c9ac5?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2jJIxT6WAIVWzDo3Ou53Q0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/59a1Bp0JQfL2mGnpL0lW2Y'},
#        'href': 'https://api.spotify.com/v1/artists/59a1Bp0JQfL2mGnpL0lW2Y',
#        'id': '59a1Bp0JQfL2mGnpL0lW2Y',
#        'name': 'Joyhauser',
#        'type': 'artist',
#        'uri': 'spotify:artist:59a1Bp0JQfL2mGnpL0lW2Y'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XCDqHX603iScKjeb9ffAG'},
#      'href': 'https://api.spotify.com/v1/albums/6XCDqHX603iScKjeb9ffAG',
#      'id': '6XCDqHX603iScKjeb9ffAG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f5d99fd21b800a41ac05697',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f5d99fd21b800a41ac05697',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f5d99fd21b800a41ac05697',
#        'width': 64}],
#      'name': 'Warped',
#      'release_date': '2020-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6XCDqHX603iScKjeb9ffAG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/59a1Bp0JQfL2mGnpL0lW2Y'},
#       'href': 'https://api.spotify.com/v1/artists/59a1Bp0JQfL2mGnpL0lW2Y',
#       'id': '59a1Bp0JQfL2mGnpL0lW2Y',
#       'name': 'Joyhauser',
#       'type': 'artist',
#       'uri': 'spotify:artist:59a1Bp0JQfL2mGnpL0lW2Y'}],
#     'disc_number': 1,
#     'duration_ms': 450457,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEBG51800122'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3jgpE2RhPNOD98t5PoYTrT'},
#     'href': 'https://api.spotify.com/v1/tracks/3jgpE2RhPNOD98t5PoYTrT',
#     'id': '3jgpE2RhPNOD98t5PoYTrT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Warped',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c784cac26731432dc2a3496e2704bd854c106a6e?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3jgpE2RhPNOD98t5PoYTrT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:47:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#        'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#        'id': '0KyUH5WmspOhuIQAnw42Fb',
#        'name': 'Paranoid London',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0wdxdBlbsDLeAYpDofB1NU'},
#      'href': 'https://api.spotify.com/v1/albums/0wdxdBlbsDLeAYpDofB1NU',
#      'id': '0wdxdBlbsDLeAYpDofB1NU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273be14e38280e7a0d113fd9acb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02be14e38280e7a0d113fd9acb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851be14e38280e7a0d113fd9acb',
#        'width': 64}],
#      'name': 'Paranoid London',
#      'release_date': '2018-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0wdxdBlbsDLeAYpDofB1NU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#       'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#       'id': '0KyUH5WmspOhuIQAnw42Fb',
#       'name': 'Paranoid London',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#     'disc_number': 1,
#     'duration_ms': 314052,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKA481500021'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1f8A5VMVtITE9D4q5UCOmh'},
#     'href': 'https://api.spotify.com/v1/tracks/1f8A5VMVtITE9D4q5UCOmh',
#     'id': '1f8A5VMVtITE9D4q5UCOmh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'We Aint',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e38c9bfc65762df68e761bec034718dabf456438?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1f8A5VMVtITE9D4q5UCOmh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L56gAwU2WofuHHOpLC0BU'},
#        'href': 'https://api.spotify.com/v1/artists/5L56gAwU2WofuHHOpLC0BU',
#        'id': '5L56gAwU2WofuHHOpLC0BU',
#        'name': 'Tiger Stripes',
#        'type': 'artist',
#        'uri': 'spotify:artist:5L56gAwU2WofuHHOpLC0BU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19NRJJ4qeyEND7snEqSuDA'},
#      'href': 'https://api.spotify.com/v1/albums/19NRJJ4qeyEND7snEqSuDA',
#      'id': '19NRJJ4qeyEND7snEqSuDA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2ffb9b5dba1f9f667770009',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2ffb9b5dba1f9f667770009',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2ffb9b5dba1f9f667770009',
#        'width': 64}],
#      'name': 'Rocket',
#      'release_date': '2021-09-17',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:19NRJJ4qeyEND7snEqSuDA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L56gAwU2WofuHHOpLC0BU'},
#       'href': 'https://api.spotify.com/v1/artists/5L56gAwU2WofuHHOpLC0BU',
#       'id': '5L56gAwU2WofuHHOpLC0BU',
#       'name': 'Tiger Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5L56gAwU2WofuHHOpLC0BU'}],
#     'disc_number': 1,
#     'duration_ms': 271127,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUR62000326'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GuIBnHk3IsaUuYLIkYEzi'},
#     'href': 'https://api.spotify.com/v1/tracks/0GuIBnHk3IsaUuYLIkYEzi',
#     'id': '0GuIBnHk3IsaUuYLIkYEzi',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fire',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/969bb13e0a8cffb535438032c27855f46f1e3148?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
# ...
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026fc7bea5f9a0b95b07ff9b8f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516fc7bea5f9a0b95b07ff9b8f',
#        'width': 64}],
#      'name': 'Into Desolation',
#      'release_date': '2019-08-12',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:2w9yhbMoQwYQnmg85JhQKW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L56gAwU2WofuHHOpLC0BU'},
#       'href': 'https://api.spotify.com/v1/artists/5L56gAwU2WofuHHOpLC0BU',
#       'id': '5L56gAwU2WofuHHOpLC0BU',
#       'name': 'Tiger Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5L56gAwU2WofuHHOpLC0BU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/06uPq3K8m6ciQKQMrlZTys'},
#       'href': 'https://api.spotify.com/v1/artists/06uPq3K8m6ciQKQMrlZTys',
#       'id': '06uPq3K8m6ciQKQMrlZTys',
#       'name': 'Mikaela',
#       'type': 'artist',
#       'uri': 'spotify:artist:06uPq3K8m6ciQKQMrlZTys'}],
#     'disc_number': 1,
#     'duration_ms': 419995,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUR61900049'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7nYvJSM0yp9tUpAJgrYoGq'},
#     'href': 'https://api.spotify.com/v1/tracks/7nYvJSM0yp9tUpAJgrYoGq',
#     'id': '7nYvJSM0yp9tUpAJgrYoGq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Recluse',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/abdfadcd802b09a808f75f9c5d273a4d44515b6d?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7nYvJSM0yp9tUpAJgrYoGq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/240wlM8vDrf6S4zCyzGj2W'},
#        'href': 'https://api.spotify.com/v1/artists/240wlM8vDrf6S4zCyzGj2W',
#        'id': '240wlM8vDrf6S4zCyzGj2W',
#        'name': 'CamelPhat',
#        'type': 'artist',
#        'uri': 'spotify:artist:240wlM8vDrf6S4zCyzGj2W'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2kPAmoZKlDB8ktz6SFPsLW'},
#        'href': 'https://api.spotify.com/v1/artists/2kPAmoZKlDB8ktz6SFPsLW',
#        'id': '2kPAmoZKlDB8ktz6SFPsLW',
#        'name': 'Will Easton',
#        'type': 'artist',
#        'uri': 'spotify:artist:2kPAmoZKlDB8ktz6SFPsLW'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/40E7a1Ciq5R1fhQnLCtXrL'},
#      'href': 'https://api.spotify.com/v1/albums/40E7a1Ciq5R1fhQnLCtXrL',
#      'id': '40E7a1Ciq5R1fhQnLCtXrL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27312bec5c2968dc8bade28e800',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0212bec5c2968dc8bade28e800',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485112bec5c2968dc8bade28e800',
#        'width': 64}],
#      'name': 'Witching Hour',
#      'release_date': '2020-10-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:40E7a1Ciq5R1fhQnLCtXrL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/240wlM8vDrf6S4zCyzGj2W'},
#       'href': 'https://api.spotify.com/v1/artists/240wlM8vDrf6S4zCyzGj2W',
#       'id': '240wlM8vDrf6S4zCyzGj2W',
#       'name': 'CamelPhat',
#       'type': 'artist',
#       'uri': 'spotify:artist:240wlM8vDrf6S4zCyzGj2W'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2kPAmoZKlDB8ktz6SFPsLW'},
#       'href': 'https://api.spotify.com/v1/artists/2kPAmoZKlDB8ktz6SFPsLW',
#       'id': '2kPAmoZKlDB8ktz6SFPsLW',
#       'name': 'Will Easton',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kPAmoZKlDB8ktz6SFPsLW'}],
#     'disc_number': 1,
#     'duration_ms': 258002,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL2001100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6gGvNSckrLcvV8RhoTFe4f'},
#     'href': 'https://api.spotify.com/v1/tracks/6gGvNSckrLcvV8RhoTFe4f',
#     'id': '6gGvNSckrLcvV8RhoTFe4f',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Witching Hour',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a533b7639f0caab4e872cbec5fb7c8fc9ab74ee3?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6gGvNSckrLcvV8RhoTFe4f'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qGp6i03fQolBNPswoWKMV'},
#        'href': 'https://api.spotify.com/v1/artists/1qGp6i03fQolBNPswoWKMV',
#        'id': '1qGp6i03fQolBNPswoWKMV',
#        'name': 'Hush & Sleep',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qGp6i03fQolBNPswoWKMV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qzZYgHdlmbJQ7tuB2kYXK'},
#      'href': 'https://api.spotify.com/v1/albums/6qzZYgHdlmbJQ7tuB2kYXK',
#      'id': '6qzZYgHdlmbJQ7tuB2kYXK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305cca7f8bffde45e45261ddc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205cca7f8bffde45e45261ddc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105cca7f8bffde45e45261ddc',
#        'width': 64}],
#      'name': 'When Angels Cry',
#      'release_date': '2020-03-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6qzZYgHdlmbJQ7tuB2kYXK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qGp6i03fQolBNPswoWKMV'},
#       'href': 'https://api.spotify.com/v1/artists/1qGp6i03fQolBNPswoWKMV',
#       'id': '1qGp6i03fQolBNPswoWKMV',
#       'name': 'Hush & Sleep',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qGp6i03fQolBNPswoWKMV'}],
#     'disc_number': 1,
#     'duration_ms': 364949,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEH742002914'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0uxc9NqCLmKOszNj2uEgMj'},
#     'href': 'https://api.spotify.com/v1/tracks/0uxc9NqCLmKOszNj2uEgMj',
#     'id': '0uxc9NqCLmKOszNj2uEgMj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'When Angels Cry',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1e2f042df958c989505bec25bb01f1eb943b4ea3?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0uxc9NqCLmKOszNj2uEgMj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:47:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#        'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#        'id': '0KyUH5WmspOhuIQAnw42Fb',
#        'name': 'Paranoid London',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59Oocb38BCohi63wnSnrcU'},
#      'href': 'https://api.spotify.com/v1/albums/59Oocb38BCohi63wnSnrcU',
#      'id': '59Oocb38BCohi63wnSnrcU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c5f7ff4b8c920d427fedf9a6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c5f7ff4b8c920d427fedf9a6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c5f7ff4b8c920d427fedf9a6',
#        'width': 64}],
#      'name': 'PL',
#      'release_date': '2019-08-30',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:59Oocb38BCohi63wnSnrcU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KyUH5WmspOhuIQAnw42Fb'},
#       'href': 'https://api.spotify.com/v1/artists/0KyUH5WmspOhuIQAnw42Fb',
#       'id': '0KyUH5WmspOhuIQAnw42Fb',
#       'name': 'Paranoid London',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KyUH5WmspOhuIQAnw42Fb'}],
#     'disc_number': 1,
#     'duration_ms': 267600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKA481900010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0uFUr8ihhZ9wVK9RIA6K8P'},
#     'href': 'https://api.spotify.com/v1/tracks/0uFUr8ihhZ9wVK9RIA6K8P',
#     'id': '0uFUr8ihhZ9wVK9RIA6K8P',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Blue-Ish - Album Edit',
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c41b08b5df7f06fa9a7e0e9376d14e8ebb83c672?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0uFUr8ihhZ9wVK9RIA6K8P'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-07-05T10:46:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#        'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#        'id': '3hteYQFiMFbJY7wS0xDymP',
#        'name': 'Gesaffelstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/74WVRhivkNSlrEyBRWGpw8'},
#      'href': 'https://api.spotify.com/v1/albums/74WVRhivkNSlrEyBRWGpw8',
#      'id': '74WVRhivkNSlrEyBRWGpw8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27363a248863d3b01895ef97063',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0263a248863d3b01895ef97063',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485163a248863d3b01895ef97063',
#        'width': 64}],
#      'name': 'Conspiracy Pt.1',
#      'release_date': '2011-04-25',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:74WVRhivkNSlrEyBRWGpw8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hteYQFiMFbJY7wS0xDymP'},
#       'href': 'https://api.spotify.com/v1/artists/3hteYQFiMFbJY7wS0xDymP',
#       'id': '3hteYQFiMFbJY7wS0xDymP',
#       'name': 'Gesaffelstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hteYQFiMFbJY7wS0xDymP'}],
#     'disc_number': 1,
#     'duration_ms': 407146,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAT391100025'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/30IgmOiBb0ytJIkQEdXWV7'},
#     'href': 'https://api.spotify.com/v1/tracks/30IgmOiBb0ytJIkQEdXWV7',
#     'id': '30IgmOiBb0ytJIkQEdXWV7',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hatred',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ea9da9a53673e06ca531dc246c6ef22ff1675777?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:30IgmOiBb0ytJIkQEdXWV7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-01-07T14:48:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/c4v85oah16bqklu0j4bfis063'},
#     'href': 'https://api.spotify.com/v1/users/c4v85oah16bqklu0j4bfis063',
#     'id': 'c4v85oah16bqklu0j4bfis063',
#     'type': 'user',
#     'uri': 'spotify:user:c4v85oah16bqklu0j4bfis063'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lsC3H1vh9YSRQckyGv0Up'},
#        'href': 'https://api.spotify.com/v1/artists/5lsC3H1vh9YSRQckyGv0Up',
#        'id': '5lsC3H1vh9YSRQckyGv0Up',
#        'name': 'Ellen Allien',
#        'type': 'artist',
#        'uri': 'spotify:artist:5lsC3H1vh9YSRQckyGv0Up'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7sm3zuZvJzilOotl9TXLic'},
#      'href': 'https://api.spotify.com/v1/albums/7sm3zuZvJzilOotl9TXLic',
#      'id': '7sm3zuZvJzilOotl9TXLic',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f50b4a5d7d9b6889a85fca8b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f50b4a5d7d9b6889a85fca8b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f50b4a5d7d9b6889a85fca8b',
#        'width': 64}],
#      'name': 'Auraa',
#      'release_date': '2020-06-12',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7sm3zuZvJzilOotl9TXLic'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lsC3H1vh9YSRQckyGv0Up'},
#       'href': 'https://api.spotify.com/v1/artists/5lsC3H1vh9YSRQckyGv0Up',
#       'id': '5lsC3H1vh9YSRQckyGv0Up',
#       'name': 'Ellen Allien',
#       'type': 'artist',
#       'uri': 'spotify:artist:5lsC3H1vh9YSRQckyGv0Up'}],
#     'disc_number': 1,
#     'duration_ms': 278742,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEAE62000026'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1hHXPeMxBtBfJnSyfLehgW'},
#     'href': 'https://api.spotify.com/v1/tracks/1hHXPeMxBtBfJnSyfLehgW',
#     'id': '1hHXPeMxBtBfJnSyfLehgW',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5KyaRdT7PQYwiDtzu5Yojt'},
#      'href': 'https://api.spotify.com/v1/tracks/5KyaRdT7PQYwiDtzu5Yojt',
#      'id': '5KyaRdT7PQYwiDtzu5Yojt',
#      'type': 'track',
#      'uri': 'spotify:track:5KyaRdT7PQYwiDtzu5Yojt'},
#     'name': 'True Romantics',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/45aadec6c84507f3532e62ab5034967091dded30?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1hHXPeMxBtBfJnSyfLehgW'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/1TZPvlws7CjSHpXgHGEoMG/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 444}

# %%
track_list = get_playlist_tracks("spotify", "1TZPvlws7CjSHpXgHGEoMG")

# %%
track_list[0]['track']['id']
# Out:
# '5rqRPLVqce2Cju2ytq59xu'

# %%
list_of_songs=[]
for index in range(1,len(track_list)):
    list_of_songs.append(sp.audio_features(track_list[index]["track"]["id"])[0])

# %%
song_df = pd.DataFrame(list_of_songs)

# %%
song_df.shape
# Out:
# (443, 18)

# %%
song_df.to_csv('electronic_444.csv', index = False)

# %%
list_of_songs_cleaned =[]

for i in list_of_songs:
    
    if i is None:
        pass
    else:
        list_of_songs_cleaned.append(i)

# %%
len(list_of_songs_cleaned)

# %%
song_df = pd.DataFrame(list_of_songs_cleaned)
