# %%
import config

# %%
c_id = config.c_id

# %%
c_se = config.c_se

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= c_id,
                                                           client_secret= c_se))

# %%
playlist = sp.user_playlist_tracks("spotify", "3iZ3zGhFAD5af7SxMfeFiv",market="GB")

# %%
print(list(playlist.keys()))
print("Total number of songs in the playlist: ",playlist["total"])
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  502
# 100

# %%
## Using this function
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
len(get_playlist_tracks("spotify", "51waoWnTP4bkSOCrBYH3Uv"))
# Out:
# 416

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3iZ3zGhFAD5af7SxMfeFiv/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2017-12-17T20:24:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#        'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#        'id': '5dXlc7MnpaTeUIsHLVe3n4',
#        'name': 'Coez',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3aKazjcDl544T21siS8lDp'},
#      'href': 'https://api.spotify.com/v1/albums/3aKazjcDl544T21siS8lDp',
#      'id': '3aKazjcDl544T21siS8lDp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27387f01b35a5806d46277a4316',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0287f01b35a5806d46277a4316',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485187f01b35a5806d46277a4316',
#        'width': 64}],
#      'name': 'Faccio un casino',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3aKazjcDl544T21siS8lDp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#       'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#       'id': '5dXlc7MnpaTeUIsHLVe3n4',
#       'name': 'Coez',
#       'type': 'artist',
#       'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#     'disc_number': 1,
#     'duration_ms': 222786,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITNTP1700008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MMJa7cjMadOSR6CFWvB1x'},
#     'href': 'https://api.spotify.com/v1/tracks/7MMJa7cjMadOSR6CFWvB1x',
#     'id': '7MMJa7cjMadOSR6CFWvB1x',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5IKWRPO5NGaeNIXF4rkbfZ'},
#      'href': 'https://api.spotify.com/v1/tracks/5IKWRPO5NGaeNIXF4rkbfZ',
#      'id': '5IKWRPO5NGaeNIXF4rkbfZ',
#      'type': 'track',
#      'uri': 'spotify:track:5IKWRPO5NGaeNIXF4rkbfZ'},
#     'name': "La musica non c'è",
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f49f7d7990ffd020b33a94a5dcb37ee53a1ab29?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7MMJa7cjMadOSR6CFWvB1x'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:24:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#        'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#        'id': '5dXlc7MnpaTeUIsHLVe3n4',
#        'name': 'Coez',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3aKazjcDl544T21siS8lDp'},
#      'href': 'https://api.spotify.com/v1/albums/3aKazjcDl544T21siS8lDp',
#      'id': '3aKazjcDl544T21siS8lDp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27387f01b35a5806d46277a4316',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0287f01b35a5806d46277a4316',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485187f01b35a5806d46277a4316',
#        'width': 64}],
#      'name': 'Faccio un casino',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3aKazjcDl544T21siS8lDp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#       'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#       'id': '5dXlc7MnpaTeUIsHLVe3n4',
#       'name': 'Coez',
#       'type': 'artist',
#       'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#     'disc_number': 1,
#     'duration_ms': 193624,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITNTP1700005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6qNXkVk19OYLu4CoqjDfZ0'},
#     'href': 'https://api.spotify.com/v1/tracks/6qNXkVk19OYLu4CoqjDfZ0',
#     'id': '6qNXkVk19OYLu4CoqjDfZ0',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7uVq49zkZEC4hI0v2exJv8'},
#      'href': 'https://api.spotify.com/v1/tracks/7uVq49zkZEC4hI0v2exJv8',
#      'id': '7uVq49zkZEC4hI0v2exJv8',
#      'type': 'track',
#      'uri': 'spotify:track:7uVq49zkZEC4hI0v2exJv8'},
#     'name': 'Faccio un casino',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a31044d19aae21758054e7165e1457945ae9b3f1?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6qNXkVk19OYLu4CoqjDfZ0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:25:11Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tBnK7LvBMgvkXuePtfywp'},
#        'href': 'https://api.spotify.com/v1/artists/5tBnK7LvBMgvkXuePtfywp',
#        'id': '5tBnK7LvBMgvkXuePtfywp',
#        'name': 'lowlow',
#        'type': 'artist',
#        'uri': 'spotify:artist:5tBnK7LvBMgvkXuePtfywp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6cPpa42ADXmibIhaziOXRx'},
#      'href': 'https://api.spotify.com/v1/albums/6cPpa42ADXmibIhaziOXRx',
#      'id': '6cPpa42ADXmibIhaziOXRx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737ecea61037cae24647645094',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027ecea61037cae24647645094',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517ecea61037cae24647645094',
#        'width': 64}],
#      'name': 'Redenzione',
#      'release_date': '2017-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6cPpa42ADXmibIhaziOXRx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tBnK7LvBMgvkXuePtfywp'},
#       'href': 'https://api.spotify.com/v1/artists/5tBnK7LvBMgvkXuePtfywp',
#       'id': '5tBnK7LvBMgvkXuePtfywp',
#       'name': 'lowlow',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tBnK7LvBMgvkXuePtfywp'}],
#     'disc_number': 1,
#     'duration_ms': 205640,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'ITZ041600141'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1yrneYDGaNVAZ3Ed7GrkYt'},
#     'href': 'https://api.spotify.com/v1/tracks/1yrneYDGaNVAZ3Ed7GrkYt',
#     'id': '1yrneYDGaNVAZ3Ed7GrkYt',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3Mf8qKBzyqKxbsilT2AC6T'},
#      'href': 'https://api.spotify.com/v1/tracks/3Mf8qKBzyqKxbsilT2AC6T',
#      'id': '3Mf8qKBzyqKxbsilT2AC6T',
#      'type': 'track',
#      'uri': 'spotify:track:3Mf8qKBzyqKxbsilT2AC6T'},
#     'name': 'Niente di più stupido di sognare',
#     'popularity': 44,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1yrneYDGaNVAZ3Ed7GrkYt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:25:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hBQ4zniNdQf1cqqo6hzuW'},
#        'href': 'https://api.spotify.com/v1/artists/3hBQ4zniNdQf1cqqo6hzuW',
#        'id': '3hBQ4zniNdQf1cqqo6hzuW',
#        'name': 'Salmo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hBQ4zniNdQf1cqqo6hzuW'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6o2ipzLDelm6yXU0v4ZOIK'},
#      'href': 'https://api.spotify.com/v1/albums/6o2ipzLDelm6yXU0v4ZOIK',
#      'id': '6o2ipzLDelm6yXU0v4ZOIK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739efeffdf7074481de1cccb39',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029efeffdf7074481de1cccb39',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519efeffdf7074481de1cccb39',
#        'width': 64}],
#      'name': 'Hellvisback',
#      'release_date': '2016-02-05',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6o2ipzLDelm6yXU0v4ZOIK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hBQ4zniNdQf1cqqo6hzuW'},
#       'href': 'https://api.spotify.com/v1/artists/3hBQ4zniNdQf1cqqo6hzuW',
#       'id': '3hBQ4zniNdQf1cqqo6hzuW',
#       'name': 'Salmo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hBQ4zniNdQf1cqqo6hzuW'}],
#     'disc_number': 1,
#     'duration_ms': 249613,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITB001500422'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0OU4v07h5oT26f4zmxzddH'},
#     'href': 'https://api.spotify.com/v1/tracks/0OU4v07h5oT26f4zmxzddH',
#     'id': '0OU4v07h5oT26f4zmxzddH',
#     'is_local': False,
#     'is_playable': True,
#     'name': '1984',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37793acab82c64effa4356c19b42a9f10622e4d0?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0OU4v07h5oT26f4zmxzddH'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:25:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#        'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#        'id': '5dXlc7MnpaTeUIsHLVe3n4',
#        'name': 'Coez',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3aKazjcDl544T21siS8lDp'},
#      'href': 'https://api.spotify.com/v1/albums/3aKazjcDl544T21siS8lDp',
#      'id': '3aKazjcDl544T21siS8lDp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27387f01b35a5806d46277a4316',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0287f01b35a5806d46277a4316',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485187f01b35a5806d46277a4316',
#        'width': 64}],
#      'name': 'Faccio un casino',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3aKazjcDl544T21siS8lDp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#       'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#       'id': '5dXlc7MnpaTeUIsHLVe3n4',
#       'name': 'Coez',
#       'type': 'artist',
#       'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#     'disc_number': 1,
#     'duration_ms': 177266,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITNTP1700012'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/381VH1JFj9q08V1OMlPU5m'},
#     'href': 'https://api.spotify.com/v1/tracks/381VH1JFj9q08V1OMlPU5m',
#     'id': '381VH1JFj9q08V1OMlPU5m',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7lA4RALtzRl7IrqSVm96AY'},
#      'href': 'https://api.spotify.com/v1/tracks/7lA4RALtzRl7IrqSVm96AY',
#      'id': '7lA4RALtzRl7IrqSVm96AY',
#      'type': 'track',
#      'uri': 'spotify:track:7lA4RALtzRl7IrqSVm96AY'},
#     'name': 'Le luci della città',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5c6eba810272aab9eb537c1d0c2f54717c09e566?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:381VH1JFj9q08V1OMlPU5m'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:25:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#        'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#        'id': '5dXlc7MnpaTeUIsHLVe3n4',
#        'name': 'Coez',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3aKazjcDl544T21siS8lDp'},
#      'href': 'https://api.spotify.com/v1/albums/3aKazjcDl544T21siS8lDp',
#      'id': '3aKazjcDl544T21siS8lDp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27387f01b35a5806d46277a4316',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0287f01b35a5806d46277a4316',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485187f01b35a5806d46277a4316',
#        'width': 64}],
#      'name': 'Faccio un casino',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3aKazjcDl544T21siS8lDp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dXlc7MnpaTeUIsHLVe3n4'},
#       'href': 'https://api.spotify.com/v1/artists/5dXlc7MnpaTeUIsHLVe3n4',
#       'id': '5dXlc7MnpaTeUIsHLVe3n4',
#       'name': 'Coez',
#       'type': 'artist',
#       'uri': 'spotify:artist:5dXlc7MnpaTeUIsHLVe3n4'}],
#     'disc_number': 1,
#     'duration_ms': 201853,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITNTP1700006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ZoeyU8BudZBCyFOR8d5kw'},
#     'href': 'https://api.spotify.com/v1/tracks/2ZoeyU8BudZBCyFOR8d5kw',
#     'id': '2ZoeyU8BudZBCyFOR8d5kw',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4zdfvfCudMSDKY9kjQbhj8'},
#      'href': 'https://api.spotify.com/v1/tracks/4zdfvfCudMSDKY9kjQbhj8',
#      'id': '4zdfvfCudMSDKY9kjQbhj8',
#      'type': 'track',
#      'uri': 'spotify:track:4zdfvfCudMSDKY9kjQbhj8'},
#     'name': 'E yo mamma',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/25aea9db7f8c69da27e068b99cf70548b1f495fc?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2ZoeyU8BudZBCyFOR8d5kw'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:26:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/59MLbXG0jLVwJup3KAd6m1'},
#        'href': 'https://api.spotify.com/v1/artists/59MLbXG0jLVwJup3KAd6m1',
#        'id': '59MLbXG0jLVwJup3KAd6m1',
#        'name': 'Mr.Rain',
#        'type': 'artist',
#        'uri': 'spotify:artist:59MLbXG0jLVwJup3KAd6m1'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4e5Dyk4i2hJt3c5CZI5dQJ'},
#      'href': 'https://api.spotify.com/v1/albums/4e5Dyk4i2hJt3c5CZI5dQJ',
#      'id': '4e5Dyk4i2hJt3c5CZI5dQJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b3a86cd6d83acc5422b332b0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b3a86cd6d83acc5422b332b0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b3a86cd6d83acc5422b332b0',
#        'width': 64}],
#      'name': 'Carillon',
#      'release_date': '2015-12-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4e5Dyk4i2hJt3c5CZI5dQJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/59MLbXG0jLVwJup3KAd6m1'},
#       'href': 'https://api.spotify.com/v1/artists/59MLbXG0jLVwJup3KAd6m1',
#       'id': '59MLbXG0jLVwJup3KAd6m1',
#       'name': 'Mr.Rain',
#       'type': 'artist',
#       'uri': 'spotify:artist:59MLbXG0jLVwJup3KAd6m1'}],
#     'disc_number': 1,
#     'duration_ms': 207250,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITUR31500008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6HVink8pF0sKYvIbxptsqO'},
#     'href': 'https://api.spotify.com/v1/tracks/6HVink8pF0sKYvIbxptsqO',
#     'id': '6HVink8pF0sKYvIbxptsqO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Carillon',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5745918c3b628e2f81aac43bcaf3a66b30dd7525?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6HVink8pF0sKYvIbxptsqO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:26:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5iot8OPcosJN9nCl7I5SdK'},
#        'href': 'https://api.spotify.com/v1/artists/5iot8OPcosJN9nCl7I5SdK',
#        'id': '5iot8OPcosJN9nCl7I5SdK',
#        'name': 'Irama',
#        'type': 'artist',
#        'uri': 'spotify:artist:5iot8OPcosJN9nCl7I5SdK'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7eqIHBSifXwjAm1EUToquq'},
#      'href': 'https://api.spotify.com/v1/albums/7eqIHBSifXwjAm1EUToquq',
#      'id': '7eqIHBSifXwjAm1EUToquq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d87d107389aad14a4f052c6a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d87d107389aad14a4f052c6a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d87d107389aad14a4f052c6a',
#        'width': 64}],
#      'name': 'Irama',
#      'release_date': '2016-02-12',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7eqIHBSifXwjAm1EUToquq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5iot8OPcosJN9nCl7I5SdK'},
#       'href': 'https://api.spotify.com/v1/artists/5iot8OPcosJN9nCl7I5SdK',
#       'id': '5iot8OPcosJN9nCl7I5SdK',
#       'name': 'Irama',
#       'type': 'artist',
#       'uri': 'spotify:artist:5iot8OPcosJN9nCl7I5SdK'}],
#     'disc_number': 1,
#     'duration_ms': 189294,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'IT9C91610101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1AXpSWeKoTGqEOikXCfYVX'},
#     'href': 'https://api.spotify.com/v1/tracks/1AXpSWeKoTGqEOikXCfYVX',
#     'id': '1AXpSWeKoTGqEOikXCfYVX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cosa resterà',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/880783998e772007bf2d5b5b5df5c8ecc298624d?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1AXpSWeKoTGqEOikXCfYVX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:26:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5iot8OPcosJN9nCl7I5SdK'},
#        'href': 'https://api.spotify.com/v1/artists/5iot8OPcosJN9nCl7I5SdK',
#        'id': '5iot8OPcosJN9nCl7I5SdK',
#        'name': 'Irama',
#        'type': 'artist',
#        'uri': 'spotify:artist:5iot8OPcosJN9nCl7I5SdK'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7eqIHBSifXwjAm1EUToquq'},
#      'href': 'https://api.spotify.com/v1/albums/7eqIHBSifXwjAm1EUToquq',
#      'id': '7eqIHBSifXwjAm1EUToquq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d87d107389aad14a4f052c6a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d87d107389aad14a4f052c6a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d87d107389aad14a4f052c6a',
#        'width': 64}],
#      'name': 'Irama',
#      'release_date': '2016-02-12',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7eqIHBSifXwjAm1EUToquq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5iot8OPcosJN9nCl7I5SdK'},
#       'href': 'https://api.spotify.com/v1/artists/5iot8OPcosJN9nCl7I5SdK',
#       'id': '5iot8OPcosJN9nCl7I5SdK',
#       'name': 'Irama',
#       'type': 'artist',
#       'uri': 'spotify:artist:5iot8OPcosJN9nCl7I5SdK'}],
#     'disc_number': 1,
#     'duration_ms': 221880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'IT9C91610102'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VQ80l4O1jpTeI5126wB0P'},
#     'href': 'https://api.spotify.com/v1/tracks/4VQ80l4O1jpTeI5126wB0P',
#     'id': '4VQ80l4O1jpTeI5126wB0P',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Tornerai da me',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/04cd8acf468a3f8ae37b9e67fd9d84b4dd40850d?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4VQ80l4O1jpTeI5126wB0P'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:27:04Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iK8weavvfS2xJCmzNzNE5'},
#        'href': 'https://api.spotify.com/v1/artists/2iK8weavvfS2xJCmzNzNE5',
#        'id': '2iK8weavvfS2xJCmzNzNE5',
#        'name': 'J-AX',
#        'type': 'artist',
#        'uri': 'spotify:artist:2iK8weavvfS2xJCmzNzNE5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pgCLfNbw5ozIfoNsvDU7i'},
#        'href': 'https://api.spotify.com/v1/artists/3pgCLfNbw5ozIfoNsvDU7i',
#        'id': '3pgCLfNbw5ozIfoNsvDU7i',
#        'name': 'Fedez',
#        'type': 'artist',
#        'uri': 'spotify:artist:3pgCLfNbw5ozIfoNsvDU7i'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WnXo5VywlMIsIRrK09nhi'},
#      'href': 'https://api.spotify.com/v1/albums/1WnXo5VywlMIsIRrK09nhi',
#      'id': '1WnXo5VywlMIsIRrK09nhi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7aad41a56f99d8eccadd72c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7aad41a56f99d8eccadd72c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7aad41a56f99d8eccadd72c',
#        'width': 64}],
#      'name': 'Comunisti col Rolex (Multiplatinum Edition)',
#      'release_date': '2017-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 61,
#      'type': 'album',
#      'uri': 'spotify:album:1WnXo5VywlMIsIRrK09nhi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iK8weavvfS2xJCmzNzNE5'},
#       'href': 'https://api.spotify.com/v1/artists/2iK8weavvfS2xJCmzNzNE5',
#       'id': '2iK8weavvfS2xJCmzNzNE5',
#       'name': 'J-AX',
#       'type': 'artist',
#       'uri': 'spotify:artist:2iK8weavvfS2xJCmzNzNE5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pgCLfNbw5ozIfoNsvDU7i'},
#       'href': 'https://api.spotify.com/v1/artists/3pgCLfNbw5ozIfoNsvDU7i',
#       'id': '3pgCLfNbw5ozIfoNsvDU7i',
#       'name': 'Fedez',
#       'type': 'artist',
#       'uri': 'spotify:artist:3pgCLfNbw5ozIfoNsvDU7i'}],
#     'disc_number': 1,
#     'duration_ms': 126093,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITB001700788'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6T7auXdjnEFnifaWc796YQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6T7auXdjnEFnifaWc796YQ',
#     'id': '6T7auXdjnEFnifaWc796YQ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Favorisca i sentimenti',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c7c19df12a7bc231c9ab60e26b152c731647e4e1?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:6T7auXdjnEFnifaWc796YQ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:27:11Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0tTS475qIqv3KXYZMXjsYy'},
#        'href': 'https://api.spotify.com/v1/artists/0tTS475qIqv3KXYZMXjsYy',
#        'id': '0tTS475qIqv3KXYZMXjsYy',
#        'name': 'Lorenzo Fragola',
#        'type': 'artist',
#        'uri': 'spotify:artist:0tTS475qIqv3KXYZMXjsYy'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0FxEbIEYdmAZ7u2oDB0Z4P'},
#      'href': 'https://api.spotify.com/v1/albums/0FxEbIEYdmAZ7u2oDB0Z4P',
#      'id': '0FxEbIEYdmAZ7u2oDB0Z4P',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273896fb5976afbd8a7a4419dad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02896fb5976afbd8a7a4419dad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851896fb5976afbd8a7a4419dad',
#        'width': 64}],
#      'name': 'Zero Gravity',
#      'release_date': '2016-03-11',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0FxEbIEYdmAZ7u2oDB0Z4P'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0tTS475qIqv3KXYZMXjsYy'},
#       'href': 'https://api.spotify.com/v1/artists/0tTS475qIqv3KXYZMXjsYy',
#       'id': '0tTS475qIqv3KXYZMXjsYy',
#       'name': 'Lorenzo Fragola',
#       'type': 'artist',
#       'uri': 'spotify:artist:0tTS475qIqv3KXYZMXjsYy'}],
#     'disc_number': 1,
#     'duration_ms': 207906,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITB001600013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15dYrloTvmcrkZ7xv5mfID'},
#     'href': 'https://api.spotify.com/v1/tracks/15dYrloTvmcrkZ7xv5mfID',
#     'id': '15dYrloTvmcrkZ7xv5mfID',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Infinite volte',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/540b0ef104812c431277d76da6e4c15ea1712ec5?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:15dYrloTvmcrkZ7xv5mfID'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:27:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tBnK7LvBMgvkXuePtfywp'},
#        'href': 'https://api.spotify.com/v1/artists/5tBnK7LvBMgvkXuePtfywp',
#        'id': '5tBnK7LvBMgvkXuePtfywp',
#        'name': 'lowlow',
#        'type': 'artist',
#        'uri': 'spotify:artist:5tBnK7LvBMgvkXuePtfywp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UFXzz9FOy7x40xpfAyDQV'},
#      'href': 'https://api.spotify.com/v1/albums/3UFXzz9FOy7x40xpfAyDQV',
#      'id': '3UFXzz9FOy7x40xpfAyDQV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27308a81ec37a5266cd5a36adf2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0208a81ec37a5266cd5a36adf2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485108a81ec37a5266cd5a36adf2',
#        'width': 64}],
#      'name': 'Incompleti',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3UFXzz9FOy7x40xpfAyDQV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tBnK7LvBMgvkXuePtfywp'},
#       'href': 'https://api.spotify.com/v1/artists/5tBnK7LvBMgvkXuePtfywp',
#       'id': '5tBnK7LvBMgvkXuePtfywp',
#       'name': 'lowlow',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tBnK7LvBMgvkXuePtfywp'}],
#     'disc_number': 1,
#     'duration_ms': 182395,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITZ041700103'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3VwuxRuADxP4LxhpBeO2nn'},
#     'href': 'https://api.spotify.com/v1/tracks/3VwuxRuADxP4LxhpBeO2nn',
#     'id': '3VwuxRuADxP4LxhpBeO2nn',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1rlJhsQfVl8ClZvDtbHqGn'},
#      'href': 'https://api.spotify.com/v1/tracks/1rlJhsQfVl8ClZvDtbHqGn',
#      'id': '1rlJhsQfVl8ClZvDtbHqGn',
#      'type': 'track',
#      'uri': 'spotify:track:1rlJhsQfVl8ClZvDtbHqGn'},
#     'name': 'Incompleti',
#     'popularity': 36,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3VwuxRuADxP4LxhpBeO2nn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-17T20:28:01Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Umo1uO9VemTgnkjeUhx8c'},
#        'href': 'https://api.spotify.com/v1/artists/4Umo1uO9VemTgnkjeUhx8c',
#        'id': '4Umo1uO9VemTgnkjeUhx8c',
#        'name': 'Enrico Nigiotti',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Umo1uO9VemTgnkjeUhx8c'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38KfDURRSexb9tA6Ll5ZT1'},
#      'href': 'https://api.spotify.com/v1/albums/38KfDURRSexb9tA6Ll5ZT1',
#      'id': '38KfDURRSexb9tA6Ll5ZT1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bca55d7b84498f0d11f61549',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bca55d7b84498f0d11f61549',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bca55d7b84498f0d11f61549',
#        'width': 64}],
#      'name': "L'amore è",
#      'release_date': '2017-12-08',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:38KfDURRSexb9tA6Ll5ZT1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Umo1uO9VemTgnkjeUhx8c'},
#       'href': 'https://api.spotify.com/v1/artists/4Umo1uO9VemTgnkjeUhx8c',
#       'id': '4Umo1uO9VemTgnkjeUhx8c',
#       'name': 'Enrico Nigiotti',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Umo1uO9VemTgnkjeUhx8c'}],
#     'disc_number': 1,
#     'duration_ms': 224840,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITB001700837'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iOHkI1AyDXfDeoXEFaP2e'},
#     'href': 'https://api.spotify.com/v1/tracks/0iOHkI1AyDXfDeoXEFaP2e',
#     'id': '0iOHkI1AyDXfDeoXEFaP2e',
#     'is_local': False,
#     'is_playable': True,
#     'name': "L'amore è",
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/99b9adca75c0d666a71ecbb1649c9f02a531919d?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iOHkI1AyDXfDeoXEFaP2e'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-19T22:22:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EA9hVIzKfFiQI0Kikz2wo'},
#        'href': 'https://api.spotify.com/v1/artists/3EA9hVIzKfFiQI0Kikz2wo',
#        'id': '3EA9hVIzKfFiQI0Kikz2wo',
#        'name': 'Andrea Bocelli',
#        'type': 'artist',
#        'uri': 'spotify:artist:3EA9hVIzKfFiQI0Kikz2wo'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2MOs2gBy14kW9jYXbv2A3O'},
#      'href': 'https://api.spotify.com/v1/albums/2MOs2gBy14kW9jYXbv2A3O',
#      'id': '2MOs2gBy14kW9jYXbv2A3O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baf9098edfd8605c55975c84',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baf9098edfd8605c55975c84',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baf9098edfd8605c55975c84',
#        'width': 64}],
#      'name': 'Perfect Symphony (Ed Sheeran & Andrea Bocelli)',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2MOs2gBy14kW9jYXbv2A3O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EA9hVIzKfFiQI0Kikz2wo'},
#       'href': 'https://api.spotify.com/v1/artists/3EA9hVIzKfFiQI0Kikz2wo',
#       'id': '3EA9hVIzKfFiQI0Kikz2wo',
#       'name': 'Andrea Bocelli',
#       'type': 'artist',
#       'uri': 'spotify:artist:3EA9hVIzKfFiQI0Kikz2wo'}],
#     'disc_number': 1,
#     'duration_ms': 265363,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1701221'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3zl7j5ua8mF4JDYuxrfo01'},
#     'href': 'https://api.spotify.com/v1/tracks/3zl7j5ua8mF4JDYuxrfo01',
#     'id': '3zl7j5ua8mF4JDYuxrfo01',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect Symphony (Ed Sheeran & Andrea Bocelli)',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a7a3d0c237792456f61c95fe4b9eff57a3cb6fc3?cid=db69a8f40bb943f8bd3d774eeca0f01d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3zl7j5ua8mF4JDYuxrfo01'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-22T06:02:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#        'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#        'id': '2FXC3k01G6Gw61bmprjgqS',
#        'name': 'Hozier',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0Uv83rRhY5QvHKkQoULRKk'},
#      'href': 'https://api.spotify.com/v1/albums/0Uv83rRhY5QvHKkQoULRKk',
#      'id': '0Uv83rRhY5QvHKkQoULRKk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a9bf5f82e32d33d4503fe7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a9bf5f82e32d33d4503fe7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a9bf5f82e32d33d4503fe7b',
#        'width': 64}],
#      'name': 'Hozier',
#      'release_date': '2014-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0Uv83rRhY5QvHKkQoULRKk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#       'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#       'id': '2FXC3k01G6Gw61bmprjgqS',
#       'name': 'Hozier',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#     'disc_number': 1,
#     'duration_ms': 241688,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'IEACJ1300031'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3dYD57lRAUcMHufyqn9GcI'},
#     'href': 'https://api.spotify.com/v1/tracks/3dYD57lRAUcMHufyqn9GcI',
#     'id': '3dYD57lRAUcMHufyqn9GcI',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0IqKeD8ZSP72KbGYyzEcAs'},
#      'href': 'https://api.spotify.com/v1/tracks/0IqKeD8ZSP72KbGYyzEcAs',
#      'id': '0IqKeD8ZSP72KbGYyzEcAs',
#      'type': 'track',
#      'uri': 'spotify:track:0IqKeD8ZSP72KbGYyzEcAs'},
#     'name': 'Take Me To Church',
#     'popularity': 85,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3dYD57lRAUcMHufyqn9GcI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-01-19T14:22:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23TFHmajVfBtlRx5MXqgoz'},
#        'href': 'https://api.spotify.com/v1/artists/23TFHmajVfBtlRx5MXqgoz',
#        'id': '23TFHmajVfBtlRx5MXqgoz',
#        'name': 'Sfera Ebbasta',
#        'type': 'artist',
#        'uri': 'spotify:artist:23TFHmajVfBtlRx5MXqgoz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YXyBqtxW2APQNBCscATw0'},
#      'href': 'https://api.spotify.com/v1/albums/5YXyBqtxW2APQNBCscATw0',
#      'id': '5YXyBqtxW2APQNBCscATw0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bdbb64093ef6f0582479ec8e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bdbb64093ef6f0582479ec8e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bdbb64093ef6f0582479ec8e',
#        'width': 64}],
#      'name': 'Rockstar (International Version)',
#      'release_date': '2018-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5YXyBqtxW2APQNBCscATw0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23TFHmajVfBtlRx5MXqgoz'},
#       'href': 'https://api.spotify.com/v1/artists/23TFHmajVfBtlRx5MXqgoz',
#       'id': '23TFHmajVfBtlRx5MXqgoz',
#       'name': 'Sfera Ebbasta',
#       'type': 'artist',
#       'uri': 'spotify:artist:23TFHmajVfBtlRx5MXqgoz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VRj0yCOv2FXJNP47XQnx5'},
#       'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#       'id': '0VRj0yCOv2FXJNP47XQnx5',
#       'name': 'Quavo',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'}],
#     'disc_number': 1,
#     'duration_ms': 210106,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'ITUM71701731'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IB44qTngIOBGYnjGZgz16'},
#     'href': 'https://api.spotify.com/v1/tracks/5IB44qTngIOBGYnjGZgz16',
#     'id': '5IB44qTngIOBGYnjGZgz16',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0dLToDou8YHYJpQltj3Ijy'},
#      'href': 'https://api.spotify.com/v1/tracks/0dLToDou8YHYJpQltj3Ijy',
#      'id': '0dLToDou8YHYJpQltj3Ijy',
#      'type': 'track',
#      'uri': 'spotify:track:0dLToDou8YHYJpQltj3Ijy'},
#     'name': 'Cupido (feat. Quavo)',
#     'popularity': 47,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5IB44qTngIOBGYnjGZgz16'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-01-21T08:11:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23TFHmajVfBtlRx5MXqgoz'},
#        'href': 'https://api.spotify.com/v1/artists/23TFHmajVfBtlRx5MXqgoz',
#        'id': '23TFHmajVfBtlRx5MXqgoz',
#        'name': 'Sfera Ebbasta',
#        'type': 'artist',
#        'uri': 'spotify:artist:23TFHmajVfBtlRx5MXqgoz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YXyBqtxW2APQNBCscATw0'},
#      'href': 'https://api.spotify.com/v1/albums/5YXyBqtxW2APQNBCscATw0',
#      'id': '5YXyBqtxW2APQNBCscATw0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bdbb64093ef6f0582479ec8e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bdbb64093ef6f0582479ec8e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bdbb64093ef6f0582479ec8e',
#        'width': 64}],
#      'name': 'Rockstar (International Version)',
#      'release_date': '2018-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5YXyBqtxW2APQNBCscATw0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23TFHmajVfBtlRx5MXqgoz'},
#       'href': 'https://api.spotify.com/v1/artists/23TFHmajVfBtlRx5MXqgoz',
#       'id': '23TFHmajVfBtlRx5MXqgoz',
#       'name': 'Sfera Ebbasta',
#       'type': 'artist',
#       'uri': 'spotify:artist:23TFHmajVfBtlRx5MXqgoz'}],
#     'disc_number': 1,
#     'duration_ms': 195946,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'ITUM71701729'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3NnbNYUCvWIOEx0wiWxq8a'},
#     'href': 'https://api.spotify.com/v1/tracks/3NnbNYUCvWIOEx0wiWxq8a',
#     'id': '3NnbNYUCvWIOEx0wiWxq8a',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3js3wKPw8VxBWtcXtwyUnA'},
#      'href': 'https://api.spotify.com/v1/tracks/3js3wKPw8VxBWtcXtwyUnA',
#      'id': '3js3wKPw8VxBWtcXtwyUnA',
#      'type': 'track',
#      'uri': 'spotify:track:3js3wKPw8VxBWtcXtwyUnA'},
#     'name': 'Rockstar',
#     'popularity': 42,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3NnbNYUCvWIOEx0wiWxq8a'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-01-25T05:37:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/056KMTw6IztdQjBmFfVyO3'},
#        'href': 'https://api.spotify.com/v1/artists/056KMTw6IztdQjBmFfVyO3',
#        'id': '056KMTw6IztdQjBmFfVyO3',
#        'name': 'Rkomi',
#        'type': 'artist',
#        'uri': 'spotify:artist:056KMTw6IztdQjBmFfVyO3'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7qs6R874LFaGWVVrPTELXc'},
#      'href': 'https://api.spotify.com/v1/albums/7qs6R874LFaGWVVrPTELXc',
#      'id': '7qs6R874LFaGWVVrPTELXc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738c0f735eb4e9d34313db26d1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028c0f735eb4e9d34313db26d1',
#        'width': 300},
#       {'height': 64,
# ...
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#        'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#        'id': '0fskdccy6fvnWMNMNPqEro',
#        'name': 'PSICOLOGI',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3q8IwSG70YDBQQNxapkx1c'},
#      'href': 'https://api.spotify.com/v1/albums/3q8IwSG70YDBQQNxapkx1c',
#      'id': '3q8IwSG70YDBQQNxapkx1c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f7bcc0622a73f546ee1a4084',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f7bcc0622a73f546ee1a4084',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f7bcc0622a73f546ee1a4084',
#        'width': 64}],
#      'name': '2001',
#      'release_date': '2019-07-19',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:3q8IwSG70YDBQQNxapkx1c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#       'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#       'id': '0fskdccy6fvnWMNMNPqEro',
#       'name': 'PSICOLOGI',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#     'disc_number': 1,
#     'duration_ms': 165000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITLGE1900060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2puGJHRifrmNO7gTAeWm0z'},
#     'href': 'https://api.spotify.com/v1/tracks/2puGJHRifrmNO7gTAeWm0z',
#     'id': '2puGJHRifrmNO7gTAeWm0z',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Guerra E Pace',
#     'popularity': 62,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2puGJHRifrmNO7gTAeWm0z'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-10T11:00:15Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#        'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#        'id': '0fskdccy6fvnWMNMNPqEro',
#        'name': 'PSICOLOGI',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yAgalklvLqCmFJiYYZ58L'},
#      'href': 'https://api.spotify.com/v1/albums/4yAgalklvLqCmFJiYYZ58L',
#      'id': '4yAgalklvLqCmFJiYYZ58L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff9eb11f7a7fd31c7ece1d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff9eb11f7a7fd31c7ece1d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff9eb11f7a7fd31c7ece1d4',
#        'width': 64}],
#      'name': '1002',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4yAgalklvLqCmFJiYYZ58L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#       'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#       'id': '0fskdccy6fvnWMNMNPqEro',
#       'name': 'PSICOLOGI',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7JL4DyVnKVldvwWoSnLtCM'},
#       'href': 'https://api.spotify.com/v1/artists/7JL4DyVnKVldvwWoSnLtCM',
#       'id': '7JL4DyVnKVldvwWoSnLtCM',
#       'name': 'Zef',
#       'type': 'artist',
#       'uri': 'spotify:artist:7JL4DyVnKVldvwWoSnLtCM'}],
#     'disc_number': 1,
#     'duration_ms': 147612,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'ITLGE1900063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2zjjFL0CdWHd7wavlAf55b'},
#     'href': 'https://api.spotify.com/v1/tracks/2zjjFL0CdWHd7wavlAf55b',
#     'id': '2zjjFL0CdWHd7wavlAf55b',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Ancora Sveglio',
#     'popularity': 39,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2zjjFL0CdWHd7wavlAf55b'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-10T11:00:21Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#        'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#        'id': '0fskdccy6fvnWMNMNPqEro',
#        'name': 'PSICOLOGI',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yAgalklvLqCmFJiYYZ58L'},
#      'href': 'https://api.spotify.com/v1/albums/4yAgalklvLqCmFJiYYZ58L',
#      'id': '4yAgalklvLqCmFJiYYZ58L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff9eb11f7a7fd31c7ece1d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff9eb11f7a7fd31c7ece1d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff9eb11f7a7fd31c7ece1d4',
#        'width': 64}],
#      'name': '1002',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4yAgalklvLqCmFJiYYZ58L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#       'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#       'id': '0fskdccy6fvnWMNMNPqEro',
#       'name': 'PSICOLOGI',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hk4xVujcyOr6USD95wcWb'},
#       'href': 'https://api.spotify.com/v1/artists/0hk4xVujcyOr6USD95wcWb',
#       'id': '0hk4xVujcyOr6USD95wcWb',
#       'name': 'Sick Luke',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hk4xVujcyOr6USD95wcWb'}],
#     'disc_number': 1,
#     'duration_ms': 170170,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITLGE1900061'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5gcwU72S7hXzrHGo0CFJTd'},
#     'href': 'https://api.spotify.com/v1/tracks/5gcwU72S7hXzrHGo0CFJTd',
#     'id': '5gcwU72S7hXzrHGo0CFJTd',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Stanotte',
#     'popularity': 38,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5gcwU72S7hXzrHGo0CFJTd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-10T11:00:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#        'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#        'id': '0fskdccy6fvnWMNMNPqEro',
#        'name': 'PSICOLOGI',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yAgalklvLqCmFJiYYZ58L'},
#      'href': 'https://api.spotify.com/v1/albums/4yAgalklvLqCmFJiYYZ58L',
#      'id': '4yAgalklvLqCmFJiYYZ58L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff9eb11f7a7fd31c7ece1d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff9eb11f7a7fd31c7ece1d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff9eb11f7a7fd31c7ece1d4',
#        'width': 64}],
#      'name': '1002',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4yAgalklvLqCmFJiYYZ58L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#       'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#       'id': '0fskdccy6fvnWMNMNPqEro',
#       'name': 'PSICOLOGI',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/51ltJZ6rB893AdzgCxSOV3'},
#       'href': 'https://api.spotify.com/v1/artists/51ltJZ6rB893AdzgCxSOV3',
#       'id': '51ltJZ6rB893AdzgCxSOV3',
#       'name': 'Greg Willen',
#       'type': 'artist',
#       'uri': 'spotify:artist:51ltJZ6rB893AdzgCxSOV3'}],
#     'disc_number': 1,
#     'duration_ms': 152000,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'ITLGE1900066'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5KVf2DaBaWci2c30tEAtJD'},
#     'href': 'https://api.spotify.com/v1/tracks/5KVf2DaBaWci2c30tEAtJD',
#     'id': '5KVf2DaBaWci2c30tEAtJD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Non Mi Piace',
#     'popularity': 48,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5KVf2DaBaWci2c30tEAtJD'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-10T11:00:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#        'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#        'id': '0fskdccy6fvnWMNMNPqEro',
#        'name': 'PSICOLOGI',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yAgalklvLqCmFJiYYZ58L'},
#      'href': 'https://api.spotify.com/v1/albums/4yAgalklvLqCmFJiYYZ58L',
#      'id': '4yAgalklvLqCmFJiYYZ58L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff9eb11f7a7fd31c7ece1d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff9eb11f7a7fd31c7ece1d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff9eb11f7a7fd31c7ece1d4',
#        'width': 64}],
#      'name': '1002',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4yAgalklvLqCmFJiYYZ58L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#       'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#       'id': '0fskdccy6fvnWMNMNPqEro',
#       'name': 'PSICOLOGI',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1sHljqzdPCaYRcFrkHW8if'},
#       'href': 'https://api.spotify.com/v1/artists/1sHljqzdPCaYRcFrkHW8if',
#       'id': '1sHljqzdPCaYRcFrkHW8if',
#       'name': 'Mr. Monkey',
#       'type': 'artist',
#       'uri': 'spotify:artist:1sHljqzdPCaYRcFrkHW8if'}],
#     'disc_number': 1,
#     'duration_ms': 162073,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITLGE1900067'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ZEFqQ8hVGdyMxddxu8Pa3'},
#     'href': 'https://api.spotify.com/v1/tracks/5ZEFqQ8hVGdyMxddxu8Pa3',
#     'id': '5ZEFqQ8hVGdyMxddxu8Pa3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Festa',
#     'popularity': 58,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5ZEFqQ8hVGdyMxddxu8Pa3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-10T11:00:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/malomelo'},
#     'href': 'https://api.spotify.com/v1/users/malomelo',
#     'id': 'malomelo',
#     'type': 'user',
#     'uri': 'spotify:user:malomelo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#        'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#        'id': '0fskdccy6fvnWMNMNPqEro',
#        'name': 'PSICOLOGI',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yAgalklvLqCmFJiYYZ58L'},
#      'href': 'https://api.spotify.com/v1/albums/4yAgalklvLqCmFJiYYZ58L',
#      'id': '4yAgalklvLqCmFJiYYZ58L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff9eb11f7a7fd31c7ece1d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff9eb11f7a7fd31c7ece1d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff9eb11f7a7fd31c7ece1d4',
#        'width': 64}],
#      'name': '1002',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4yAgalklvLqCmFJiYYZ58L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fskdccy6fvnWMNMNPqEro'},
#       'href': 'https://api.spotify.com/v1/artists/0fskdccy6fvnWMNMNPqEro',
#       'id': '0fskdccy6fvnWMNMNPqEro',
#       'name': 'PSICOLOGI',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fskdccy6fvnWMNMNPqEro'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6adzJ1E1UUrcSid2CsDZ6i'},
#       'href': 'https://api.spotify.com/v1/artists/6adzJ1E1UUrcSid2CsDZ6i',
#       'id': '6adzJ1E1UUrcSid2CsDZ6i',
#       'name': 'Voga',
#       'type': 'artist',
#       'uri': 'spotify:artist:6adzJ1E1UUrcSid2CsDZ6i'}],
#     'disc_number': 1,
#     'duration_ms': 169714,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITLGE1900068'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/16D4XNPuct4HoUECi60j16'},
#     'href': 'https://api.spotify.com/v1/tracks/16D4XNPuct4HoUECi60j16',
#     'id': '16D4XNPuct4HoUECi60j16',
#     'is_local': False,
#     'is_playable': True,
#     'name': '2001',
#     'popularity': 49,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:16D4XNPuct4HoUECi60j16'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/3iZ3zGhFAD5af7SxMfeFiv/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 502}

# %%
track_list = get_playlist_tracks("spotify", "3iZ3zGhFAD5af7SxMfeFiv")

# %%
track_list[0]['track']['id']
# Out:
# '7MMJa7cjMadOSR6CFWvB1x'

# %%
list_of_songs=[]
for index in range(1,len(track_list)):
    list_of_songs.append(sp.audio_features(track_list[index]["track"]["id"])[0])

# %%
song_df = pd.DataFrame(list_of_songs)

# %%
song_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.742   0.490    7    -6.482     1       0.0513       0.56200
# 1           0.667   0.659    7    -7.101     1       0.2660       0.10300
# 2           0.703   0.764    8    -4.532     1       0.2900       0.22500
# 3           0.582   0.544    7    -6.591     1       0.0362       0.39300
# 4           0.711   0.232    0   -10.165     1       0.0795       0.83800
# ..            ...     ...  ...       ...   ...          ...           ...
# 496         0.437   0.309    2    -9.561     1       0.0405       0.86000
# 497         0.647   0.857    0    -4.230     1       0.0654       0.00725
# 498         0.617   0.682    8    -7.860     1       0.0358       0.27200
# 499         0.579   0.452    9    -4.760     0       0.0387       0.65000
# 500         0.801   0.617    5    -6.531     1       0.0307       0.36300
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.1910    0.509   82.994  audio_features
# 1            0.000000    0.1200    0.206   85.169  audio_features
# 2            0.000000    0.1580    0.746   89.818  audio_features
# 3            0.000002    0.1350    0.142  129.933  audio_features
# 4            0.000000    0.0844    0.361  139.785  audio_features
# ..                ...       ...      ...      ...             ...
# 496          0.000000    0.1550    0.309  131.012  audio_features
# 497          0.000000    0.0608    0.659  130.007  audio_features
# 498          0.000005    0.2650    0.399  150.002  audio_features
# 499          0.000000    0.6290    0.645  110.566  audio_features
# 500          0.000000    0.0747    0.834  141.016  audio_features
#
#                          id                                   uri  \
# 0    6qNXkVk19OYLu4CoqjDfZ0  spotify:track:6qNXkVk19OYLu4CoqjDfZ0
# 1    1yrneYDGaNVAZ3Ed7GrkYt  spotify:track:1yrneYDGaNVAZ3Ed7GrkYt
# 2    0OU4v07h5oT26f4zmxzddH  spotify:track:0OU4v07h5oT26f4zmxzddH
# 3    381VH1JFj9q08V1OMlPU5m  spotify:track:381VH1JFj9q08V1OMlPU5m
# 4    2ZoeyU8BudZBCyFOR8d5kw  spotify:track:2ZoeyU8BudZBCyFOR8d5kw
# ..                      ...                                   ...
# 496  3j6JJZs12M8UBx8b9GZ9T1  spotify:track:3j6JJZs12M8UBx8b9GZ9T1
# 497  0Dz9zyx2w3zYtRK6yp3VKD  spotify:track:0Dz9zyx2w3zYtRK6yp3VKD
# 498  56YZNYnzdsXTZiWttI6BfQ  spotify:track:56YZNYnzdsXTZiWttI6BfQ
# 499  2tMD7T1XVP32cwiDY8UjNO  spotify:track:2tMD7T1XVP32cwiDY8UjNO
# 500  1qgHaDzcOhqm4padSaiDZa  spotify:track:1qgHaDzcOhqm4padSaiDZa
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6qNXkVk19OYL...
# 1    https://api.spotify.com/v1/tracks/1yrneYDGaNVA...
# 2    https://api.spotify.com/v1/tracks/0OU4v07h5oT2...
# 3    https://api.spotify.com/v1/tracks/381VH1JFj9q0...
# 4    https://api.spotify.com/v1/tracks/2ZoeyU8BudZB...
# ..                                                 ...
# 496  https://api.spotify.com/v1/tracks/3j6JJZs12M8U...
# 497  https://api.spotify.com/v1/tracks/0Dz9zyx2w3zY...
# 498  https://api.spotify.com/v1/tracks/56YZNYnzdsXT...
# 499  https://api.spotify.com/v1/tracks/2tMD7T1XVP32...
# 500  https://api.spotify.com/v1/tracks/1qgHaDzcOhqm...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6qNX...       193624
# 1    https://api.spotify.com/v1/audio-analysis/1yrn...       205640
# 2    https://api.spotify.com/v1/audio-analysis/0OU4...       249613
# 3    https://api.spotify.com/v1/audio-analysis/381V...       177267
# 4    https://api.spotify.com/v1/audio-analysis/2Zoe...       201853
# ..                                                 ...          ...
# 496  https://api.spotify.com/v1/audio-analysis/3j6J...       146224
# 497  https://api.spotify.com/v1/audio-analysis/0Dz9...       195923
# 498  https://api.spotify.com/v1/audio-analysis/56YZ...       210367
# 499  https://api.spotify.com/v1/audio-analysis/2tMD...       196500
# 500  https://api.spotify.com/v1/audio-analysis/1qgH...       211064
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 496               4
# 497               4
# 498               4
# 499               4
# 500               4
#
# [501 rows x 18 columns]

# %%
song_df.to_csv('indie_rap_pop_501.csv', index = False)

# %%
list_of_songs_cleaned =[]

for i in list_of_songs:
    
    if i is None:
        pass
    else:
        list_of_songs_cleaned.append(i)

# %%
len(list_of_songs_cleaned)

# %%
song_df = pd.DataFrame(list_of_songs_cleaned)
