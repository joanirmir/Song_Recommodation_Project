# %%
#https://open.spotify.com/playlist/1C49yxU1XBkoq5yaVDbJwx

# %%
import config
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.c_id, client_secret=config.c_se))
playlist = sp.user_playlist_tracks("spotify", "1C49yxU1XBkoq5yaVDbJwx",market='GB')
print(list(playlist.keys()))
print("Total number of songs in the playlist: ",playlist["total"]) 
len(playlist['items'])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  8310
# 100

# %%
import pandas as pd
features=[]
for index in range(0,len(playlist["items"])):
    features.append(sp.audio_features(playlist["items"][index]["track"]["uri"])[0])
while playlist['next']:
    playlist = sp.next(playlist)
    for index in range(0,len(playlist["items"])):
        if sp.audio_features(playlist["items"][index]["track"]["uri"])[0]is None: 
            continue
        else:                           
            features.append(sp.audio_features(playlist["items"][index]["track"]["uri"])[0])
ultimate_party_mix = pd.DataFrame(features)
# Out:
# Expected id of type track but found type Reunion spotify:local:M83:Hurry+Up%2C+We%27re+Dreaming.:Reunion:235

# %%
ultimate_party_mix
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.669   0.698    1    -7.971     1       0.0713      0.024300
# 1            0.544   0.897    3    -6.056     0       0.0471      0.241000
# 2            0.514   0.942    9    -8.433     1       0.0502      0.282000
# 3            0.527   0.835    6    -5.298     1       0.0433      0.016600
# 4            0.767   0.881    9    -3.988     1       0.0301      0.001330
# ...            ...     ...  ...       ...   ...          ...           ...
# 8304         0.662   0.735    9    -6.999     1       0.0288      0.026900
# 8305         0.966   0.509    7    -7.559     0       0.1230      0.496000
# 8306         0.848   0.821    2    -5.408     0       0.0527      0.016900
# 8307         0.731   0.904   10    -4.774     0       0.0349      0.008610
# 8308         0.793   0.886   10    -5.071     0       0.0445      0.000755
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.0782    0.600   83.987  audio_features
# 1             0.000000    0.1300    0.647  157.170  audio_features
# 2             0.000066    0.1700    0.912  159.847  audio_features
# 3             0.000000    0.2490    0.654  125.983  audio_features
# 4             0.000139    0.0551    0.961  130.018  audio_features
# ...                ...       ...      ...      ...             ...
# 8304          0.002140    0.0871    0.889  114.009  audio_features
# 8305          0.000000    0.0799    0.646  108.013  audio_features
# 8306          0.000403    0.0962    0.249  125.051  audio_features
# 8307          0.000164    0.0916    0.328  121.030  audio_features
# 8308          0.878000    0.2960    0.285  124.040  audio_features
#
#                           id                                   uri  \
# 0     2BdSaGVMxZzEeJYjjrlo6n  spotify:track:2BdSaGVMxZzEeJYjjrlo6n
# 1     34x6hEJgGAOQvmlMql5Ige  spotify:track:34x6hEJgGAOQvmlMql5Ige
# 2     4ebcE2SmkG7nplvzFAWRu7  spotify:track:4ebcE2SmkG7nplvzFAWRu7
# 3     0ct6r3EGTcMLPtrXHDvVjc  spotify:track:0ct6r3EGTcMLPtrXHDvVjc
# 4     1mvZErZBp7WZT3HfGBykao  spotify:track:1mvZErZBp7WZT3HfGBykao
# ...                      ...                                   ...
# 8304  1sKWhJrFT6PGoXIo2mkgKq  spotify:track:1sKWhJrFT6PGoXIo2mkgKq
# 8305  7voSun33hCNkIrjxaj3g47  spotify:track:7voSun33hCNkIrjxaj3g47
# 8306  6GomT970rCOkKAyyrwJeZi  spotify:track:6GomT970rCOkKAyyrwJeZi
# 8307  3YOZWCREvKsxhcZNJix5xd  spotify:track:3YOZWCREvKsxhcZNJix5xd
# 8308  0B3H6se7MYo3D7BmzfvdVN  spotify:track:0B3H6se7MYo3D7BmzfvdVN
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2BdSaGVMxZzE...
# 1     https://api.spotify.com/v1/tracks/34x6hEJgGAOQ...
# 2     https://api.spotify.com/v1/tracks/4ebcE2SmkG7n...
# 3     https://api.spotify.com/v1/tracks/0ct6r3EGTcML...
# 4     https://api.spotify.com/v1/tracks/1mvZErZBp7WZ...
# ...                                                 ...
# 8304  https://api.spotify.com/v1/tracks/1sKWhJrFT6PG...
# 8305  https://api.spotify.com/v1/tracks/7voSun33hCNk...
# 8306  https://api.spotify.com/v1/tracks/6GomT970rCOk...
# 8307  https://api.spotify.com/v1/tracks/3YOZWCREvKsx...
# 8308  https://api.spotify.com/v1/tracks/0B3H6se7MYo3...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2BdS...       261707
# 1     https://api.spotify.com/v1/audio-analysis/34x6...       215133
# 2     https://api.spotify.com/v1/audio-analysis/4ebc...       175267
# 3     https://api.spotify.com/v1/audio-analysis/0ct6...       176658
# 4     https://api.spotify.com/v1/audio-analysis/1mvZ...       209800
# ...                                                 ...          ...
# 8304  https://api.spotify.com/v1/audio-analysis/1sKW...       236067
# 8305  https://api.spotify.com/v1/audio-analysis/7voS...       186953
# 8306  https://api.spotify.com/v1/audio-analysis/6Gom...       157445
# 8307  https://api.spotify.com/v1/audio-analysis/3YOZ...       130413
# 8308  https://api.spotify.com/v1/audio-analysis/0B3H...       158725
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 8304               4
# 8305               4
# 8306               4
# 8307               4
# 8308               4
#
# [8309 rows x 18 columns]

# %%
ultimate_party_mix.to_csv("ultimate_party_mix.csv",index=False)
